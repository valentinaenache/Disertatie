# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf
df = pd.read_excel('^IXIC.xlsx')

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)
TRAIN_SPLIT = 0.7
tf.random.set_seed(13)

# %%
#Predictia seriei de timp univariate
uni_data = df['Log return']
uni_data.index = df['Date']
print(uni_data.head())

uni_data.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()
# Out:
# Date
# 2012-01-03    0.0000
# 2012-01-04   -0.0001
# 2012-01-05    0.0081
# 2012-01-06    0.0016
# 2012-01-09    0.0009
# Name: Log return, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

uni_data_train, uni_data_test = train_test_split(uni_data, train_size=0.7, test_size=0.3, shuffle=False)
uni_data = uni_data.values

# %%
uni_train_mean = uni_data_train.mean()
uni_train_std = uni_data_train.std()

uni_data = (uni_data-uni_train_mean)/uni_train_std

univariate_past_history = 100
univariate_future_target = 10

x_train_uni, y_train_uni = univariate_data(uni_data, 0, len(uni_data_train),
                                           univariate_past_history,
                                           univariate_future_target)
x_val_uni, y_val_uni = univariate_data(uni_data, len(uni_data_train), None,
                                       univariate_past_history,
                                       univariate_future_target)

print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-0.07185497]
#  [-0.08290246]
#  [ 0.82299158]
#  [ 0.10490484]
#  [ 0.02757242]
#  [ 0.9887039 ]
#  [ 0.27061716]
#  [ 0.49156693]
#  [-0.64632436]
#  [ 0.63518428]
#  [ 1.59631576]
#  [ 0.66832674]
#  [-0.1381399 ]
#  [-0.17128237]
#  [ 0.02757242]
#  [ 1.1765112 ]
#  [-0.58003943]
#  [ 0.37004456]
#  [-0.24861478]
#  [ 0.00547745]
#  [ 1.2759386 ]
#  [ 0.37004456]
#  [ 1.69574315]
#  [-0.21547232]
#  [ 0.00547745]
#  [ 0.37004456]
#  [ 0.35899707]
#  [-0.95565403]
#  [ 0.96660892]
#  [-0.04976   ]
#  [-0.67946683]
#  [ 1.58526827]
#  [-0.37013716]
#  [-0.19337734]
#  [-0.64632436]
#  [ 0.82299158]
#  [ 0.18223726]
#  [ 0.01652493]
#  [ 0.69042172]
#  [-0.81203669]
#  [ 0.74565916]
#  [-0.54689697]
#  [-1.03298645]
#  [-1.58536086]
#  [ 0.88927651]
#  [ 1.23174864]
#  [ 0.59099432]
#  [-0.24861478]
#  [ 1.99402533]
#  [-0.03871251]
#  [ 0.49156693]
#  [-0.11604493]
#  [ 0.75670665]
#  [-0.22651981]
#  [-0.02766502]
#  [-0.50270701]
#  [ 0.09385735]
#  [ 1.88355045]
#  [-0.14918739]
#  [-0.6131819 ]
#  [-0.41432711]
#  [-0.20442483]
#  [ 0.93346646]
#  [-0.29280474]
#  [-1.69583575]
#  [ 0.37004456]
#  [-1.27603119]
#  [-2.1156403 ]
#  [ 0.85613404]
#  [ 1.35327101]
#  [-1.68478826]
#  [-0.91146408]
#  [ 1.91669292]
#  [-0.48061204]
#  [-0.94460654]
#  [-0.33699469]
#  [-1.1766038 ]
#  [-0.40327962]
#  [ 2.43592486]
#  [ 0.69042172]
#  [ 0.60204181]
#  [-0.90041659]
#  [ 0.07176238]
#  [ 0.27061716]
#  [-1.3644111 ]
#  [-2.57963481]
#  [-0.01661753]
#  [-0.50270701]
#  [-0.50270701]
#  [-0.11604493]
#  [-0.06080748]
#  [-1.25393622]
#  [-0.40327962]
#  [-0.82308417]
#  [-2.41392248]
#  [-1.452791  ]
#  [ 2.61268468]
#  [-0.39223213]
#  [ 0.35899707]
#  [-0.49165953]]
#
#  Target to predict
# -1.9720229530716702

# %%
def create_time_steps(length):
  return list(range(-length, 0))

def show_plot(plot_data, delta, title):
  labels = ['Istoric', 'Valoarea reală din viitor', 'Predicția modelului']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

    plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example')
plt.show()

# %%
def baseline(history):
  return np.mean(history)

show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 0,
           'Model predicție de bază')
plt.show()

BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)

EVALUATION_INTERVAL = 200
EPOCHS = 100

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
for x, y in val_univariate.take(1):
  plot = show_plot([x[0].numpy(), y[0].numpy(),
                    simple_lstm_model.predict(x)[0]], 0, 'Predicție LTSM')
  plot.show()

plt.show()
# Out:
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 7s 26ms/step - loss: 0.7213 - val_loss: 1.2316
# Epoch 2/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7207 - val_loss: 1.2334
# Epoch 3/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.7197 - val_loss: 1.2415
# Epoch 4/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.7191 - val_loss: 1.2466
# Epoch 5/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7190 - val_loss: 1.2506
# Epoch 6/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.7177 - val_loss: 1.2533
# Epoch 7/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.7172 - val_loss: 1.2570
# Epoch 8/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.7170 - val_loss: 1.2600
# Epoch 9/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7160 - val_loss: 1.2655
# Epoch 10/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.7149 - val_loss: 1.2633
# Epoch 11/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.7133 - val_loss: 1.2682
# Epoch 12/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7103 - val_loss: 1.2701
# Epoch 13/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.7063 - val_loss: 1.2704
# Epoch 14/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.7039 - val_loss: 1.2694
# Epoch 15/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7023 - val_loss: 1.2765
# Epoch 16/100
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7013 - val_loss: 1.2723
# Epoch 17/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7011 - val_loss: 1.2804
# Epoch 18/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6986 - val_loss: 1.2791
# Epoch 19/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6985 - val_loss: 1.2867
# Epoch 20/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6983 - val_loss: 1.2766
# Epoch 21/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6977 - val_loss: 1.2872
# Epoch 22/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6965 - val_loss: 1.2864
# Epoch 23/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6956 - val_loss: 1.2847
# Epoch 24/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6958 - val_loss: 1.2795
# Epoch 25/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6943 - val_loss: 1.2874
# Epoch 26/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6944 - val_loss: 1.2888
# Epoch 27/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6920 - val_loss: 1.2884
# Epoch 28/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6927 - val_loss: 1.2857
# Epoch 29/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6918 - val_loss: 1.2877
# Epoch 30/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6913 - val_loss: 1.2878
# Epoch 31/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6912 - val_loss: 1.2885
# Epoch 32/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6906 - val_loss: 1.2867
# Epoch 33/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6905 - val_loss: 1.2848
# Epoch 34/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6902 - val_loss: 1.2875
# Epoch 35/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6892 - val_loss: 1.2907
# Epoch 36/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6885 - val_loss: 1.2915
# Epoch 37/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6955 - val_loss: 1.2867
# Epoch 38/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6885 - val_loss: 1.2858
# Epoch 39/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6882 - val_loss: 1.2910
# Epoch 40/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6870 - val_loss: 1.2913
# Epoch 41/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6877 - val_loss: 1.2897
# Epoch 42/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6880 - val_loss: 1.2881
# Epoch 43/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6877 - val_loss: 1.2953
# Epoch 44/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6878 - val_loss: 1.2909
# Epoch 45/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6874 - val_loss: 1.2893
# Epoch 46/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6877 - val_loss: 1.2895
# Epoch 47/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6857 - val_loss: 1.2886
# Epoch 48/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6885 - val_loss: 1.2919
# Epoch 49/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6879 - val_loss: 1.2899
# Epoch 50/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6860 - val_loss: 1.2880
# Epoch 51/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6861 - val_loss: 1.2921
# Epoch 52/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6920 - val_loss: 1.2853
# Epoch 53/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6885 - val_loss: 1.2877
# Epoch 54/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6848 - val_loss: 1.2860
# Epoch 55/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6872 - val_loss: 1.2868
# Epoch 56/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6887 - val_loss: 1.2840
# Epoch 57/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6839 - val_loss: 1.2855
# Epoch 58/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6858 - val_loss: 1.2863
# Epoch 59/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6826 - val_loss: 1.2860
# Epoch 60/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6832 - val_loss: 1.2828
# Epoch 61/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6838 - val_loss: 1.2814
# Epoch 62/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6828 - val_loss: 1.2853
# Epoch 63/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6815 - val_loss: 1.2836
# Epoch 64/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6806 - val_loss: 1.2860
# Epoch 65/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6798 - val_loss: 1.2874
# Epoch 66/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6818 - val_loss: 1.2873
# Epoch 67/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6816 - val_loss: 1.2866
# Epoch 68/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6805 - val_loss: 1.2857
# Epoch 69/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6787 - val_loss: 1.2864
# Epoch 70/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6784 - val_loss: 1.2867
# Epoch 71/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6782 - val_loss: 1.2857
# Epoch 72/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6783 - val_loss: 1.2841
# Epoch 73/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6765 - val_loss: 1.2863
# Epoch 74/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6766 - val_loss: 1.2861
# Epoch 75/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6774 - val_loss: 1.2857
# Epoch 76/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6735 - val_loss: 1.2871
# Epoch 77/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6720 - val_loss: 1.2878
# Epoch 78/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6725 - val_loss: 1.2892
# Epoch 79/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6727 - val_loss: 1.2881
# Epoch 80/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6730 - val_loss: 1.2886
# Epoch 81/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6734 - val_loss: 1.2886
# Epoch 82/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6701 - val_loss: 1.2902
# Epoch 83/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6705 - val_loss: 1.2897
# Epoch 84/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6717 - val_loss: 1.2910
# Epoch 85/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6714 - val_loss: 1.2910
# Epoch 86/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6692 - val_loss: 1.2917
# Epoch 87/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6685 - val_loss: 1.2932
# Epoch 88/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6698 - val_loss: 1.2918
# Epoch 89/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6687 - val_loss: 1.2935
# Epoch 90/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6675 - val_loss: 1.2936
# Epoch 91/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6683 - val_loss: 1.2936
# Epoch 92/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6644 - val_loss: 1.2953
# Epoch 93/100
# 200/200 [==============================] - 6s 30ms/step - loss: 0.6652 - val_loss: 1.2957
# Epoch 94/100
# 200/200 [==============================] - 6s 30ms/step - loss: 0.6649 - val_loss: 1.2956
# Epoch 95/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6631 - val_loss: 1.2960
# Epoch 96/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6639 - val_loss: 1.2951
# Epoch 97/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6644 - val_loss: 1.2965
# Epoch 98/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6615 - val_loss: 1.2981
# Epoch 99/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6621 - val_loss: 1.2982
# Epoch 100/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6621 - val_loss: 1.2979

# %%
#Forecast a multivariate time series

features_considered = ['Open', 'Log return']
features = df[features_considered]
features.index = df['Date']
features.head()

features.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()

# %%
multi_data_train, multi_data_test = train_test_split(features, train_size=0.7, test_size=0.3, shuffle=False)

dataset = features.values
data_mean = dataset[:len(multi_data_train)].mean(axis=0)
data_std = dataset[:len(multi_data_train)].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

past_history = 100
future_target = 10
STEP = 1
x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   len(multi_data_train), past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               len(multi_data_train), None, past_history,
                                               future_target, STEP,
                                               single_step=True)

print ('Single window of past history : {}'.format(x_train_single[0].shape))

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)

single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Single window of past history : (100, 2)
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 14s 60ms/step - loss: 0.7195 - val_loss: 1.2346
# Epoch 2/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.7168 - val_loss: 1.2365
# Epoch 3/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.7120 - val_loss: 1.2389
# Epoch 4/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.7073 - val_loss: 1.2360
# Epoch 5/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.7014 - val_loss: 1.2422
# Epoch 6/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6959 - val_loss: 1.2451
# Epoch 7/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6886 - val_loss: 1.2465
# Epoch 8/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6800 - val_loss: 1.2445
# Epoch 9/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6719 - val_loss: 1.2425
# Epoch 10/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6636 - val_loss: 1.2452
# Epoch 11/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6552 - val_loss: 1.2462
# Epoch 12/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6485 - val_loss: 1.2434
# Epoch 13/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6415 - val_loss: 1.2462
# Epoch 14/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6348 - val_loss: 1.2531
# Epoch 15/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6283 - val_loss: 1.2542
# Epoch 16/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6220 - val_loss: 1.2541
# Epoch 17/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6156 - val_loss: 1.2599
# Epoch 18/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6094 - val_loss: 1.2566
# Epoch 19/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6041 - val_loss: 1.2592
# Epoch 20/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5961 - val_loss: 1.2696
# Epoch 21/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.5888 - val_loss: 1.2650
# Epoch 22/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.5827 - val_loss: 1.2702
# Epoch 23/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.5752 - val_loss: 1.2675
# Epoch 24/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5723 - val_loss: 1.2736
# Epoch 25/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5659 - val_loss: 1.2748
# Epoch 26/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5583 - val_loss: 1.2737
# Epoch 27/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5538 - val_loss: 1.2698
# Epoch 28/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5465 - val_loss: 1.2714
# Epoch 29/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5405 - val_loss: 1.2749
# Epoch 30/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5363 - val_loss: 1.2716
# Epoch 31/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5272 - val_loss: 1.2771
# Epoch 32/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5213 - val_loss: 1.2799
# Epoch 33/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5161 - val_loss: 1.2849
# Epoch 34/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5090 - val_loss: 1.2861
# Epoch 35/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5028 - val_loss: 1.2890
# Epoch 36/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5005 - val_loss: 1.2883
# Epoch 37/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.4926 - val_loss: 1.2915
# Epoch 38/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.4872 - val_loss: 1.2999
# Epoch 39/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4813 - val_loss: 1.2971
# Epoch 40/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4753 - val_loss: 1.3022
# Epoch 41/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4677 - val_loss: 1.3010
# Epoch 42/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4633 - val_loss: 1.3153
# Epoch 43/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4580 - val_loss: 1.3150
# Epoch 44/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4517 - val_loss: 1.3173
# Epoch 45/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4468 - val_loss: 1.3181
# Epoch 46/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.4410 - val_loss: 1.3266
# Epoch 47/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4350 - val_loss: 1.3254
# Epoch 48/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4328 - val_loss: 1.3318
# Epoch 49/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4264 - val_loss: 1.3240
# Epoch 50/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4210 - val_loss: 1.3303
# Epoch 51/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4190 - val_loss: 1.3258
# Epoch 52/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4159 - val_loss: 1.3244
# Epoch 53/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.4103 - val_loss: 1.3271
# Epoch 54/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4045 - val_loss: 1.3306
# Epoch 55/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4009 - val_loss: 1.3289
# Epoch 56/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3987 - val_loss: 1.3348
# Epoch 57/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3999 - val_loss: 1.3363
# Epoch 58/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3933 - val_loss: 1.3388
# Epoch 59/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3888 - val_loss: 1.3415
# Epoch 60/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3821 - val_loss: 1.3402
# Epoch 61/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3811 - val_loss: 1.3360
# Epoch 62/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3771 - val_loss: 1.3371
# Epoch 63/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3775 - val_loss: 1.3387
# Epoch 64/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3711 - val_loss: 1.3384
# Epoch 65/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3661 - val_loss: 1.3448
# Epoch 66/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3630 - val_loss: 1.3470
# Epoch 67/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3593 - val_loss: 1.3421
# Epoch 68/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3556 - val_loss: 1.3456
# Epoch 69/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3538 - val_loss: 1.3465
# Epoch 70/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3515 - val_loss: 1.3515
# Epoch 71/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3458 - val_loss: 1.3499
# Epoch 72/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3431 - val_loss: 1.3541
# Epoch 73/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3394 - val_loss: 1.3571
# Epoch 74/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3354 - val_loss: 1.3619
# Epoch 75/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3345 - val_loss: 1.3668
# Epoch 76/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3321 - val_loss: 1.3649
# Epoch 77/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3273 - val_loss: 1.3655
# Epoch 78/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3254 - val_loss: 1.3654
# Epoch 79/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3222 - val_loss: 1.3704
# Epoch 80/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3192 - val_loss: 1.3754
# Epoch 81/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3170 - val_loss: 1.3862
# Epoch 82/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3147 - val_loss: 1.3874
# Epoch 83/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3132 - val_loss: 1.3886
# Epoch 84/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3099 - val_loss: 1.3864
# Epoch 85/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3097 - val_loss: 1.3856
# Epoch 86/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3053 - val_loss: 1.3984
# Epoch 87/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3061 - val_loss: 1.4018
# Epoch 88/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3027 - val_loss: 1.4083
# Epoch 89/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3002 - val_loss: 1.4155
# Epoch 90/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2978 - val_loss: 1.3988
# Epoch 91/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2947 - val_loss: 1.4073
# Epoch 92/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2934 - val_loss: 1.3918
# Epoch 93/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2914 - val_loss: 1.4068
# Epoch 94/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2910 - val_loss: 1.4063
# Epoch 95/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2881 - val_loss: 1.4218
# Epoch 96/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2846 - val_loss: 1.4095
# Epoch 97/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2837 - val_loss: 1.4144
# Epoch 98/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.2816 - val_loss: 1.4106
# Epoch 99/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2798 - val_loss: 1.4192
# Epoch 100/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2815 - val_loss: 1.4220

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Pierderea setului de testare')
  plt.plot(epochs, val_loss, 'r', label='Pierderea setului de validare')
  plt.title('Capacitatea de generalizare a modelului')
  plt.legend()

  plt.show()
plt.show()

# %%
plot_train_history(single_step_history,
                   'Predicția într-o singură etapă')

for x, y in val_data_single.take(1):
  plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'Single Step Prediction')
  plot.show()
plt.show()

# %%
#Multi-Step model

future_target = 5
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 len(multi_data_train), past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             len(multi_data_train), None, past_history,
                                             future_target, STEP)

print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (100, 2)
#
#  Target temperature to predict : (5,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='Istoric')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'b',
           label='Valori reale viitoare')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'r',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()
plt.show()

for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))
plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)

multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)

plot_train_history(multi_step_history, 'Capacitatea de învățare a modelului')
# Out:
# (256, 5)
# Epoch 1/100
# 200/200 [==============================] - 26s 116ms/step - loss: 0.7225 - val_loss: 1.2338
# Epoch 2/100
# 200/200 [==============================] - 24s 120ms/step - loss: 0.7159 - val_loss: 3.4570
# Epoch 3/100
# 200/200 [==============================] - 29s 143ms/step - loss: 0.7031 - val_loss: 1.6081
# Epoch 4/100
# 200/200 [==============================] - 29s 144ms/step - loss: 0.6890 - val_loss: 1.2678
# Epoch 5/100
# 200/200 [==============================] - 28s 141ms/step - loss: 0.6780 - val_loss: 1.3270
# Epoch 6/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.6674 - val_loss: 3.2836
# Epoch 7/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.6584 - val_loss: 1.4079
# Epoch 8/100
# 200/200 [==============================] - 30s 151ms/step - loss: 0.6503 - val_loss: 1.4399
# Epoch 9/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.6429 - val_loss: 1.4444
# Epoch 10/100
# 200/200 [==============================] - 27s 136ms/step - loss: 3.6576 - val_loss: 1.4664
# Epoch 11/100
# 200/200 [==============================] - 27s 136ms/step - loss: 379246.7812 - val_loss: 2909480.5000
# Epoch 12/100
# 200/200 [==============================] - 30s 149ms/step - loss: 118074336.0000 - val_loss: 3.0737
# Epoch 13/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.6564 - val_loss: 1.8484
# Epoch 14/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.7986 - val_loss: 1.8383
# Epoch 15/100
# 200/200 [==============================] - 28s 139ms/step - loss: 214.9591 - val_loss: 1.6410
# Epoch 16/100
# 200/200 [==============================] - 27s 137ms/step - loss: 1.1844 - val_loss: 3.1231
# Epoch 17/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.6237 - val_loss: 1.4024
# Epoch 18/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.6309 - val_loss: 1.4753
# Epoch 19/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.6339 - val_loss: 1.4132
# Epoch 20/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.6065 - val_loss: 1.4143
# Epoch 21/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.6029 - val_loss: 1.4137
# Epoch 22/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5963 - val_loss: 1.4128
# Epoch 23/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.5909 - val_loss: 1.4387
# Epoch 24/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5862 - val_loss: 1.4461
# Epoch 25/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.5818 - val_loss: 1.4620
# Epoch 26/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5778 - val_loss: 1.4676
# Epoch 27/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5730 - val_loss: 1.4847
# Epoch 28/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5685 - val_loss: 1.4834
# Epoch 29/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5645 - val_loss: 1.4996
# Epoch 30/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.5608 - val_loss: 1.4913
# Epoch 31/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.5567 - val_loss: 1.5032
# Epoch 32/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.5532 - val_loss: 1.5201
# Epoch 33/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5490 - val_loss: 1.5035
# Epoch 34/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.5453 - val_loss: 1.5035
# Epoch 35/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5410 - val_loss: 1.5245
# Epoch 36/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.5372 - val_loss: 1.5172
# Epoch 37/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.5335 - val_loss: 1.5098
# Epoch 38/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5301 - val_loss: 1.5465
# Epoch 39/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.5269 - val_loss: 1.5422
# Epoch 40/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.5236 - val_loss: 1.5898
# Epoch 41/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.5201 - val_loss: 1.5917
# Epoch 42/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5176 - val_loss: 1.5742
# Epoch 43/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.5146 - val_loss: 1.5789
# Epoch 44/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.5107 - val_loss: 1.6132
# Epoch 45/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.5082 - val_loss: 1.5556
# Epoch 46/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5047 - val_loss: 1.5776
# Epoch 47/100
# 200/200 [==============================] - 28s 141ms/step - loss: 0.5022 - val_loss: 1.5479
# Epoch 48/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4989 - val_loss: 1.5501
# Epoch 49/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4961 - val_loss: 1.5542
# Epoch 50/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4938 - val_loss: 1.5539
# Epoch 51/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4905 - val_loss: 1.5563
# Epoch 52/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4871 - val_loss: 1.5462
# Epoch 53/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.4845 - val_loss: 1.5475
# Epoch 54/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.4817 - val_loss: 1.5504
# Epoch 55/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4788 - val_loss: 1.5470
# Epoch 56/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4759 - val_loss: 1.5418
# Epoch 57/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4733 - val_loss: 1.5421
# Epoch 58/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4697 - val_loss: 1.5534
# Epoch 59/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.4669 - val_loss: 1.5513
# Epoch 60/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.4633 - val_loss: 1.5671
# Epoch 61/100
# 200/200 [==============================] - 28s 141ms/step - loss: 0.4597 - val_loss: 1.5547
# Epoch 62/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.4561 - val_loss: 1.5459
# Epoch 63/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.4521 - val_loss: 1.5434
# Epoch 64/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4479 - val_loss: 1.5568
# Epoch 65/100
# 200/200 [==============================] - 28s 142ms/step - loss: 0.4442 - val_loss: 1.5763
# Epoch 66/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.4403 - val_loss: 1.5847
# Epoch 67/100
# 200/200 [==============================] - 28s 141ms/step - loss: 0.4358 - val_loss: 1.5676
# Epoch 68/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4320 - val_loss: 1.5878
# Epoch 69/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.4268 - val_loss: 1.5655
# Epoch 70/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.4216 - val_loss: 1.5547
# Epoch 71/100
# 200/200 [==============================] - 28s 141ms/step - loss: 0.4161 - val_loss: 1.5559
# Epoch 72/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4107 - val_loss: 1.5315
# Epoch 73/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4067 - val_loss: 1.5615
# Epoch 74/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.4020 - val_loss: 1.5298
# Epoch 75/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3983 - val_loss: 1.5344
# Epoch 76/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3945 - val_loss: 1.5384
# Epoch 77/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.3901 - val_loss: 1.5208
# Epoch 78/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3864 - val_loss: 1.5452
# Epoch 79/100
# 200/200 [==============================] - 28s 141ms/step - loss: 0.3820 - val_loss: 1.5376
# Epoch 80/100
# 200/200 [==============================] - 28s 142ms/step - loss: 0.3779 - val_loss: 1.5228
# Epoch 81/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.3735 - val_loss: 1.5233
# Epoch 82/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.3691 - val_loss: 1.5314
# Epoch 83/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.3662 - val_loss: 1.5350
# Epoch 84/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.3620 - val_loss: 1.5233
# Epoch 85/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3580 - val_loss: 1.5287
# Epoch 86/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.3543 - val_loss: 1.5233
# Epoch 87/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3508 - val_loss: 1.5384
# Epoch 88/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.3470 - val_loss: 1.5290
# Epoch 89/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.3426 - val_loss: 1.5236
# Epoch 90/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3396 - val_loss: 1.5234
# Epoch 91/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3359 - val_loss: 1.5337
# Epoch 92/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.3330 - val_loss: 1.5451
# Epoch 93/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3296 - val_loss: 1.5593
# Epoch 94/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3259 - val_loss: 1.5501
# Epoch 95/100
# 200/200 [==============================] - 28s 141ms/step - loss: 0.3229 - val_loss: 1.5695
# Epoch 96/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.3203 - val_loss: 1.5258
# Epoch 97/100
# 200/200 [==============================] - 28s 142ms/step - loss: 0.3175 - val_loss: 1.5433
# Epoch 98/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.3142 - val_loss: 1.5298
# Epoch 99/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.3113 - val_loss: 1.5389
# Epoch 100/100
# 200/200 [==============================] - 23s 117ms/step - loss: 0.3090 - val_loss: 1.5716

# %%
#Predict a multi-step future

predicted=(multi_step_model.predict(x)[0])*data_std[1]+data_mean[1]
history=(x[0])*data_std[1]+data_mean[1]
true_future=(y[0])*data_std[1]+data_mean[1]

for x, y in val_data_multi.take(1):
  multi_step_plot(history, true_future, predicted)


from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(true_future, predicted))
print(rmse)
# Out:
# 0.012067534841408654
