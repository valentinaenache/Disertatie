# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf
df = pd.read_excel('^IXIC.xlsx')

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)
TRAIN_SPLIT = 0.7
tf.random.set_seed(13)

# %%
#Predictia seriei de timp univariate
uni_data = df['Log return']
uni_data.index = df['Date']
print(uni_data.head())

uni_data.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()
# Out:
# Date
# 2012-01-03    0.0000
# 2012-01-04   -0.0001
# 2012-01-05    0.0081
# 2012-01-06    0.0016
# 2012-01-09    0.0009
# Name: Log return, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

uni_data_train, uni_data_test = train_test_split(uni_data, train_size=0.7, test_size=0.3, shuffle=False)
uni_data = uni_data.values

# %%
uni_train_mean = uni_data_train.mean()
uni_train_std = uni_data_train.std()

uni_data = (uni_data-uni_train_mean)/uni_train_std

univariate_past_history = 100
univariate_future_target = 10

x_train_uni, y_train_uni = univariate_data(uni_data, 0, len(uni_data_train),
                                           univariate_past_history,
                                           univariate_future_target)
x_val_uni, y_val_uni = univariate_data(uni_data, len(uni_data_train), None,
                                       univariate_past_history,
                                       univariate_future_target)

print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-0.07185497]
#  [-0.08290246]
#  [ 0.82299158]
#  [ 0.10490484]
#  [ 0.02757242]
#  [ 0.9887039 ]
#  [ 0.27061716]
#  [ 0.49156693]
#  [-0.64632436]
#  [ 0.63518428]
#  [ 1.59631576]
#  [ 0.66832674]
#  [-0.1381399 ]
#  [-0.17128237]
#  [ 0.02757242]
#  [ 1.1765112 ]
#  [-0.58003943]
#  [ 0.37004456]
#  [-0.24861478]
#  [ 0.00547745]
#  [ 1.2759386 ]
#  [ 0.37004456]
#  [ 1.69574315]
#  [-0.21547232]
#  [ 0.00547745]
#  [ 0.37004456]
#  [ 0.35899707]
#  [-0.95565403]
#  [ 0.96660892]
#  [-0.04976   ]
#  [-0.67946683]
#  [ 1.58526827]
#  [-0.37013716]
#  [-0.19337734]
#  [-0.64632436]
#  [ 0.82299158]
#  [ 0.18223726]
#  [ 0.01652493]
#  [ 0.69042172]
#  [-0.81203669]
#  [ 0.74565916]
#  [-0.54689697]
#  [-1.03298645]
#  [-1.58536086]
#  [ 0.88927651]
#  [ 1.23174864]
#  [ 0.59099432]
#  [-0.24861478]
#  [ 1.99402533]
#  [-0.03871251]
#  [ 0.49156693]
#  [-0.11604493]
#  [ 0.75670665]
#  [-0.22651981]
#  [-0.02766502]
#  [-0.50270701]
#  [ 0.09385735]
#  [ 1.88355045]
#  [-0.14918739]
#  [-0.6131819 ]
#  [-0.41432711]
#  [-0.20442483]
#  [ 0.93346646]
#  [-0.29280474]
#  [-1.69583575]
#  [ 0.37004456]
#  [-1.27603119]
#  [-2.1156403 ]
#  [ 0.85613404]
#  [ 1.35327101]
#  [-1.68478826]
#  [-0.91146408]
#  [ 1.91669292]
#  [-0.48061204]
#  [-0.94460654]
#  [-0.33699469]
#  [-1.1766038 ]
#  [-0.40327962]
#  [ 2.43592486]
#  [ 0.69042172]
#  [ 0.60204181]
#  [-0.90041659]
#  [ 0.07176238]
#  [ 0.27061716]
#  [-1.3644111 ]
#  [-2.57963481]
#  [-0.01661753]
#  [-0.50270701]
#  [-0.50270701]
#  [-0.11604493]
#  [-0.06080748]
#  [-1.25393622]
#  [-0.40327962]
#  [-0.82308417]
#  [-2.41392248]
#  [-1.452791  ]
#  [ 2.61268468]
#  [-0.39223213]
#  [ 0.35899707]
#  [-0.49165953]]
#
#  Target to predict
# -1.9720229530716702

# %%
def create_time_steps(length):
  return list(range(-length, 0))

def show_plot(plot_data, delta, title):
  labels = ['Istoric', 'Valoarea reală din viitor', 'Predicția modelului']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

    plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example')
plt.show()

# %%
def baseline(history):
  return np.mean(history)

show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 0,
           'Model predicție de bază')
plt.show()

BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)

EVALUATION_INTERVAL = 200
EPOCHS = 100

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
for x, y in val_univariate.take(1):
  plot = show_plot([x[0].numpy(), y[0].numpy(),
                    simple_lstm_model.predict(x)[0]], 0, 'Predicție LTSM')
  plot.show()

plt.show()
# Out:
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 25s 106ms/step - loss: 0.7213 - val_loss: 1.2316
# Epoch 2/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.7207 - val_loss: 1.2334
# Epoch 3/100
# 200/200 [==============================] - 15s 75ms/step - loss: 0.7197 - val_loss: 1.2415
# Epoch 4/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.7191 - val_loss: 1.2466
# Epoch 5/100
# 200/200 [==============================] - 14s 68ms/step - loss: 0.7190 - val_loss: 1.2506
# Epoch 6/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.7177 - val_loss: 1.2533
# Epoch 7/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.7172 - val_loss: 1.2570
# Epoch 8/100
# 200/200 [==============================] - 14s 72ms/step - loss: 0.7170 - val_loss: 1.2600
# Epoch 9/100
# 200/200 [==============================] - 14s 68ms/step - loss: 0.7160 - val_loss: 1.2655
# Epoch 10/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.7149 - val_loss: 1.2633
# Epoch 11/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.7133 - val_loss: 1.2682
# Epoch 12/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.7103 - val_loss: 1.2701
# Epoch 13/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.7063 - val_loss: 1.2704
# Epoch 14/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.7039 - val_loss: 1.2694
# Epoch 15/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.7023 - val_loss: 1.2765
# Epoch 16/100
# 200/200 [==============================] - 14s 70ms/step - loss: 0.7013 - val_loss: 1.2723
# Epoch 17/100
# 200/200 [==============================] - 14s 72ms/step - loss: 0.7011 - val_loss: 1.2804
# Epoch 18/100
# 200/200 [==============================] - 14s 71ms/step - loss: 0.6986 - val_loss: 1.2791
# Epoch 19/100
# 200/200 [==============================] - 14s 68ms/step - loss: 0.6985 - val_loss: 1.2867
# Epoch 20/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6983 - val_loss: 1.2766
# Epoch 21/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6977 - val_loss: 1.2872
# Epoch 22/100
# 200/200 [==============================] - 14s 68ms/step - loss: 0.6965 - val_loss: 1.2864
# Epoch 23/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6956 - val_loss: 1.2847
# Epoch 24/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6958 - val_loss: 1.2795
# Epoch 25/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6943 - val_loss: 1.2874
# Epoch 26/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6944 - val_loss: 1.2888
# Epoch 27/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6920 - val_loss: 1.2884
# Epoch 28/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6927 - val_loss: 1.2857
# Epoch 29/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6918 - val_loss: 1.2877
# Epoch 30/100
# 200/200 [==============================] - 14s 71ms/step - loss: 0.6913 - val_loss: 1.2878
# Epoch 31/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6912 - val_loss: 1.2885
# Epoch 32/100
# 200/200 [==============================] - 14s 70ms/step - loss: 0.6906 - val_loss: 1.2867
# Epoch 33/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6905 - val_loss: 1.2848
# Epoch 34/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6902 - val_loss: 1.2875
# Epoch 35/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6892 - val_loss: 1.2907
# Epoch 36/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6885 - val_loss: 1.2915
# Epoch 37/100
# 200/200 [==============================] - 14s 72ms/step - loss: 0.6955 - val_loss: 1.2867
# Epoch 38/100
# 200/200 [==============================] - 14s 68ms/step - loss: 0.6885 - val_loss: 1.2858
# Epoch 39/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.6882 - val_loss: 1.2910
# Epoch 40/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6870 - val_loss: 1.2913
# Epoch 41/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6877 - val_loss: 1.2897
# Epoch 42/100
# 200/200 [==============================] - 13s 62ms/step - loss: 0.6880 - val_loss: 1.2881
# Epoch 43/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6877 - val_loss: 1.2953
# Epoch 44/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6878 - val_loss: 1.2909
# Epoch 45/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6874 - val_loss: 1.2893
# Epoch 46/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6877 - val_loss: 1.2895
# Epoch 47/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6857 - val_loss: 1.2886
# Epoch 48/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6885 - val_loss: 1.2919
# Epoch 49/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6879 - val_loss: 1.2899
# Epoch 50/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6860 - val_loss: 1.2880
# Epoch 51/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6861 - val_loss: 1.2921
# Epoch 52/100
# 200/200 [==============================] - 12s 63ms/step - loss: 0.6920 - val_loss: 1.2853
# Epoch 53/100
# 200/200 [==============================] - 14s 68ms/step - loss: 0.6885 - val_loss: 1.2877
# Epoch 54/100
# 200/200 [==============================] - 14s 68ms/step - loss: 0.6848 - val_loss: 1.2860
# Epoch 55/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6872 - val_loss: 1.2868
# Epoch 56/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6887 - val_loss: 1.2840
# Epoch 57/100
# 200/200 [==============================] - 14s 71ms/step - loss: 0.6839 - val_loss: 1.2855
# Epoch 58/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6858 - val_loss: 1.2863
# Epoch 59/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6826 - val_loss: 1.2860
# Epoch 60/100
# 200/200 [==============================] - 14s 71ms/step - loss: 0.6832 - val_loss: 1.2828
# Epoch 61/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6838 - val_loss: 1.2814
# Epoch 62/100
# 200/200 [==============================] - 14s 71ms/step - loss: 0.6828 - val_loss: 1.2853
# Epoch 63/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6815 - val_loss: 1.2836
# Epoch 64/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6806 - val_loss: 1.2860
# Epoch 65/100
# 200/200 [==============================] - 14s 72ms/step - loss: 0.6798 - val_loss: 1.2874
# Epoch 66/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6818 - val_loss: 1.2873
# Epoch 67/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6816 - val_loss: 1.2866
# Epoch 68/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6735 - val_loss: 1.2871
# Epoch 77/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6720 - val_loss: 1.2878
# Epoch 78/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6725 - val_loss: 1.2892
# Epoch 79/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6727 - val_loss: 1.2881
# Epoch 80/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6730 - val_loss: 1.2886
# Epoch 81/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6734 - val_loss: 1.2886
# Epoch 82/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6701 - val_loss: 1.2902
# Epoch 83/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6705 - val_loss: 1.2897
# Epoch 84/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6717 - val_loss: 1.2910
# Epoch 85/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6714 - val_loss: 1.2910
# Epoch 86/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6692 - val_loss: 1.2917
# Epoch 87/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6685 - val_loss: 1.2932
# Epoch 88/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6698 - val_loss: 1.2918
# Epoch 89/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6687 - val_loss: 1.2935
# Epoch 90/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6675 - val_loss: 1.2936
# Epoch 91/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6683 - val_loss: 1.2936
# Epoch 92/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6644 - val_loss: 1.2953
# Epoch 93/100
# 200/200 [==============================] - 13s 68ms/step - loss: 0.6652 - val_loss: 1.2957
# Epoch 94/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6649 - val_loss: 1.2956
# Epoch 95/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.6631 - val_loss: 1.2960
# Epoch 96/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6639 - val_loss: 1.2951
# Epoch 97/100
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6644 - val_loss: 1.2965
# Epoch 98/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6615 - val_loss: 1.2981
# Epoch 99/100
# 200/200 [==============================] - 8s 41ms/step - loss: 0.6621 - val_loss: 1.2982
# Epoch 100/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.6621 - val_loss: 1.2979

# %%
#Forecast a multivariate time series

features_considered = ['Close', 'Log return']
features = df[features_considered]
features.index = df['Date']
features.head()

features.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()

# %%
multi_data_train, multi_data_test = train_test_split(features, train_size=0.7, test_size=0.3, shuffle=False)

dataset = features.values
data_mean = dataset[:len(multi_data_train)].mean(axis=0)
data_std = dataset[:len(multi_data_train)].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

past_history = 100
future_target = 10
STEP = 1
x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   len(multi_data_train), past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               len(multi_data_train), None, past_history,
                                               future_target, STEP,
                                               single_step=True)

print ('Single window of past history : {}'.format(x_train_single[0].shape))

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)

single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Single window of past history : (100, 2)
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 106s 223ms/step - loss: 0.7195 - val_loss: 1.2341
# Epoch 2/100
# 200/200 [==============================] - 37s 185ms/step - loss: 0.7168 - val_loss: 1.2350
# Epoch 3/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.5717 - val_loss: 1.2737
# Epoch 27/100
# 200/200 [==============================] - 35s 174ms/step - loss: 0.5642 - val_loss: 1.2814
# Epoch 28/100
# 200/200 [==============================] - 35s 177ms/step - loss: 0.5586 - val_loss: 1.2816
# Epoch 29/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.5530 - val_loss: 1.2861
# Epoch 30/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.5502 - val_loss: 1.2827
# Epoch 31/100
# 200/200 [==============================] - 35s 175ms/step - loss: 0.5429 - val_loss: 1.2956
# Epoch 32/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.5354 - val_loss: 1.2956
# Epoch 33/100
# 200/200 [==============================] - 34s 168ms/step - loss: 0.5363 - val_loss: 1.2943
# Epoch 34/100
# 200/200 [==============================] - 33s 166ms/step - loss: 0.5251 - val_loss: 1.3011
# Epoch 35/100
# 200/200 [==============================] - 36s 180ms/step - loss: 0.5206 - val_loss: 1.3110
# Epoch 36/100
# 200/200 [==============================] - 34s 173ms/step - loss: 0.5139 - val_loss: 1.3103
# Epoch 37/100
# 200/200 [==============================] - 35s 175ms/step - loss: 0.5080 - val_loss: 1.3270
# Epoch 38/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.4999 - val_loss: 1.3306
# Epoch 39/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.4928 - val_loss: 1.3395
# Epoch 40/100
# 200/200 [==============================] - 33s 168ms/step - loss: 0.4881 - val_loss: 1.3449
# Epoch 41/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.4830 - val_loss: 1.3508
# Epoch 42/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.4770 - val_loss: 1.3488
# Epoch 43/100
# 200/200 [==============================] - 35s 174ms/step - loss: 0.4718 - val_loss: 1.3592
# Epoch 44/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.4658 - val_loss: 1.3567
# Epoch 45/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.4601 - val_loss: 1.3653
# Epoch 46/100
# 200/200 [==============================] - 33s 166ms/step - loss: 0.4562 - val_loss: 1.3631
# Epoch 47/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.4597 - val_loss: 1.3716
# Epoch 48/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.4520 - val_loss: 1.3861
# Epoch 49/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3047 - val_loss: 1.6012
# Epoch 93/100
# 200/200 [==============================] - 22s 111ms/step - loss: 0.3033 - val_loss: 1.6182
# Epoch 94/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.2998 - val_loss: 1.6020
# Epoch 95/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.2962 - val_loss: 1.5969
# Epoch 96/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.2955 - val_loss: 1.6228
# Epoch 97/100
# 200/200 [==============================] - 25s 127ms/step - loss: 0.2903 - val_loss: 1.6251
# Epoch 98/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.2900 - val_loss: 1.6307
# Epoch 99/100
# 200/200 [==============================] - 24s 121ms/step - loss: 0.2902 - val_loss: 1.6366
# Epoch 100/100
# 200/200 [==============================] - 25s 125ms/step - loss: 0.2895 - val_loss: 1.6343

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Pierderea setului de testare')
  plt.plot(epochs, val_loss, 'r', label='Pierderea setului de validare')
  plt.title('Capacitatea de generalizare a modelului')
  plt.legend()

  plt.show()
plt.show()

# %%
plot_train_history(single_step_history,
                   'Predicția într-o singură etapă')

for x, y in val_data_single.take(1):
  plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'Single Step Prediction')
  plot.show()
plt.show()

# %%
#Multi-Step model

future_target = 5
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 len(multi_data_train), past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             len(multi_data_train), None, past_history,
                                             future_target, STEP)

print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (100, 2)
#
#  Target temperature to predict : (5,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='Istoric')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'b',
           label='Valori reale viitoare')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'r',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()
plt.show()

for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))
plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)

multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)

plot_train_history(multi_step_history, 'Capacitatea de învățare a modelului')
# Out:
# (256, 5)
# Epoch 1/100
# 200/200 [==============================] - 34s 143ms/step - loss: 0.7227 - val_loss: 1.2250
# Epoch 2/100
# 200/200 [==============================] - 28s 142ms/step - loss: 0.7171 - val_loss: 1.2404
# Epoch 3/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.7067 - val_loss: 1.2545
# Epoch 4/100
# 200/200 [==============================] - 26s 128ms/step - loss: 0.6938 - val_loss: 1.3963
# Epoch 5/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.6801 - val_loss: 11.3432
# Epoch 6/100
# 200/200 [==============================] - 30s 149ms/step - loss: 0.6716 - val_loss: 6.6718
# Epoch 7/100
# 200/200 [==============================] - 28s 139ms/step - loss: 0.9119 - val_loss: 1.4964
# Epoch 8/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.6681 - val_loss: 1.3706
# Epoch 9/100
# 200/200 [==============================] - 26s 132ms/step - loss: 0.6583 - val_loss: 1.4165
# Epoch 10/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.6519 - val_loss: 1.4245
# Epoch 11/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.6457 - val_loss: 1.7628
# Epoch 12/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.6393 - val_loss: 1.4831
# Epoch 13/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.6328 - val_loss: 1.5752
# Epoch 14/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.6279 - val_loss: 1.5846
# Epoch 15/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.6213 - val_loss: 1.5605
# Epoch 16/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.6162 - val_loss: 1.6304
# Epoch 17/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.6110 - val_loss: 1.5911
# Epoch 18/100
# 200/200 [==============================] - 26s 132ms/step - loss: 0.6062 - val_loss: 1.5580
# Epoch 19/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.6019 - val_loss: 1.6322
# Epoch 20/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5976 - val_loss: 1.5663
# Epoch 21/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.5936 - val_loss: 1.5564
# Epoch 22/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.5894 - val_loss: 1.5268
# Epoch 23/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.5851 - val_loss: 1.5139
# Epoch 24/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.5811 - val_loss: 1.5087
# Epoch 25/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.5773 - val_loss: 1.5167
# Epoch 26/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.5741 - val_loss: 1.5142
# Epoch 27/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5700 - val_loss: 1.4746
# Epoch 28/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5660 - val_loss: 1.5195
# Epoch 29/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5619 - val_loss: 1.5147
# Epoch 30/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5585 - val_loss: 1.4678
# Epoch 31/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.5546 - val_loss: 1.4900
# Epoch 32/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.5513 - val_loss: 1.4874
# Epoch 33/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5479 - val_loss: 1.5186
# Epoch 34/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.5435 - val_loss: 1.5023
# Epoch 35/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5402 - val_loss: 1.5087
# Epoch 36/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5368 - val_loss: 1.5698
# Epoch 37/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.5323 - val_loss: 1.5157
# Epoch 38/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.5291 - val_loss: 1.5208
# Epoch 39/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5245 - val_loss: 1.5222
# Epoch 40/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.5205 - val_loss: 1.5238
# Epoch 41/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5173 - val_loss: 1.5308
# Epoch 42/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.5142 - val_loss: 1.5417
# Epoch 43/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.5092 - val_loss: 1.5326
# Epoch 44/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.5054 - val_loss: 1.5680
# Epoch 45/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.5022 - val_loss: 1.6048
# Epoch 46/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4993 - val_loss: 1.5855
# Epoch 47/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4953 - val_loss: 1.6181
# Epoch 48/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4924 - val_loss: 1.5989
# Epoch 49/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4898 - val_loss: 1.6165
# Epoch 50/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.4867 - val_loss: 1.6243
# Epoch 51/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.4840 - val_loss: 1.6611
# Epoch 52/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.4825 - val_loss: 1.6408
# Epoch 53/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4793 - val_loss: 1.6923
# Epoch 54/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4758 - val_loss: 1.6520
# Epoch 55/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.4736 - val_loss: 1.6408
# Epoch 56/100
# 200/200 [==============================] - 26s 132ms/step - loss: 0.4712 - val_loss: 1.6592
# Epoch 57/100
# 200/200 [==============================] - 26s 132ms/step - loss: 0.4680 - val_loss: 1.6777
# Epoch 58/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4665 - val_loss: 1.6503
# Epoch 59/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4635 - val_loss: 1.6784
# Epoch 60/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4607 - val_loss: 1.6679
# Epoch 61/100
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4581 - val_loss: 1.6563
# Epoch 62/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4553 - val_loss: 1.6891
# Epoch 63/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.4528 - val_loss: 1.6409
# Epoch 64/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4501 - val_loss: 1.6445
# Epoch 65/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.4469 - val_loss: 1.6304
# Epoch 66/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4432 - val_loss: 1.6415
# Epoch 67/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.4406 - val_loss: 1.6056
# Epoch 68/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4371 - val_loss: 1.6219
# Epoch 69/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4336 - val_loss: 1.5829
# Epoch 70/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4299 - val_loss: 1.5541
# Epoch 71/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.4262 - val_loss: 1.5690
# Epoch 72/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4222 - val_loss: 1.5593
# Epoch 73/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4184 - val_loss: 1.5289
# Epoch 74/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.4145 - val_loss: 1.5319
# Epoch 75/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.4111 - val_loss: 1.5452
# Epoch 76/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.4073 - val_loss: 1.5197
# Epoch 77/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4032 - val_loss: 1.5189
# Epoch 78/100
# 200/200 [==============================] - 26s 132ms/step - loss: 0.3991 - val_loss: 1.5141
# Epoch 79/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.3950 - val_loss: 1.5130
# Epoch 80/100
# 200/200 [==============================] - 27s 138ms/step - loss: 0.3917 - val_loss: 1.4989
# Epoch 81/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3879 - val_loss: 1.4821
# Epoch 82/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3837 - val_loss: 1.4930
# Epoch 83/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3797 - val_loss: 1.4866
# Epoch 84/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3760 - val_loss: 1.4768
# Epoch 85/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3722 - val_loss: 1.4708
# Epoch 86/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3691 - val_loss: 1.4675
# Epoch 87/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3641 - val_loss: 1.4841
# Epoch 88/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3595 - val_loss: 1.4784
# Epoch 89/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.3556 - val_loss: 1.4744
# Epoch 90/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.3521 - val_loss: 1.4734
# Epoch 91/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3490 - val_loss: 1.4752
# Epoch 92/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3445 - val_loss: 1.4730
# Epoch 93/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3411 - val_loss: 1.4792
# Epoch 94/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.3371 - val_loss: 1.4728
# Epoch 95/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3337 - val_loss: 1.4644
# Epoch 96/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.3296 - val_loss: 1.4599
# Epoch 97/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3264 - val_loss: 1.4825
# Epoch 98/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.3233 - val_loss: 1.4676
# Epoch 99/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.3197 - val_loss: 1.4808
# Epoch 100/100
# 200/200 [==============================] - 27s 137ms/step - loss: 0.3174 - val_loss: 1.4770

# %%
#Predict a multi-step future

predicted=(multi_step_model.predict(x)[0])*data_std[1]+data_mean[1]
history=(x[0])*data_std[1]+data_mean[1]
true_future=(y[0])*data_std[1]+data_mean[1]

for x, y in val_data_multi.take(1):
  multi_step_plot(history, true_future, predicted)


from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(true_future, predicted))
print(rmse)
# Out:
# 0.010316777999092143
