# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf
df = pd.read_excel('^IXIC.xlsx')

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)
TRAIN_SPLIT = 0.7
tf.random.set_seed(13)

# %%
#Predictia seriei de timp univariate
uni_data = df['Log return']
uni_data.index = df['Date']
print(uni_data.head())

uni_data.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()
# Out:
# Date
# 2012-01-03    0.0000
# 2012-01-04   -0.0001
# 2012-01-05    0.0081
# 2012-01-06    0.0016
# 2012-01-09    0.0009
# Name: Log return, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

uni_data_train, uni_data_test = train_test_split(uni_data, train_size=0.7, test_size=0.3, shuffle=False)
uni_data = uni_data.values

# %%
uni_train_mean = uni_data_train.mean()
uni_train_std = uni_data_train.std()

uni_data = (uni_data-uni_train_mean)/uni_train_std

univariate_past_history = 100
univariate_future_target = 10

x_train_uni, y_train_uni = univariate_data(uni_data, 0, len(uni_data_train),
                                           univariate_past_history,
                                           univariate_future_target)
x_val_uni, y_val_uni = univariate_data(uni_data, len(uni_data_train), None,
                                       univariate_past_history,
                                       univariate_future_target)

print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-0.07185497]
#  [-0.08290246]
#  [ 0.82299158]
#  [ 0.10490484]
#  [ 0.02757242]
#  [ 0.9887039 ]
#  [ 0.27061716]
#  [ 0.49156693]
#  [-0.64632436]
#  [ 0.63518428]
#  [ 1.59631576]
#  [ 0.66832674]
#  [-0.1381399 ]
#  [-0.17128237]
#  [ 0.02757242]
#  [ 1.1765112 ]
#  [-0.58003943]
#  [ 0.37004456]
#  [-0.24861478]
#  [ 0.00547745]
#  [ 1.2759386 ]
#  [ 0.37004456]
#  [ 1.69574315]
#  [-0.21547232]
#  [ 0.00547745]
#  [ 0.37004456]
#  [ 0.35899707]
#  [-0.95565403]
#  [ 0.96660892]
#  [-0.04976   ]
#  [-0.67946683]
#  [ 1.58526827]
#  [-0.37013716]
#  [-0.19337734]
#  [-0.64632436]
#  [ 0.82299158]
#  [ 0.18223726]
#  [ 0.01652493]
#  [ 0.69042172]
#  [-0.81203669]
#  [ 0.74565916]
#  [-0.54689697]
#  [-1.03298645]
#  [-1.58536086]
#  [ 0.88927651]
#  [ 1.23174864]
#  [ 0.59099432]
#  [-0.24861478]
#  [ 1.99402533]
#  [-0.03871251]
#  [ 0.49156693]
#  [-0.11604493]
#  [ 0.75670665]
#  [-0.22651981]
#  [-0.02766502]
#  [-0.50270701]
#  [ 0.09385735]
#  [ 1.88355045]
#  [-0.14918739]
#  [-0.6131819 ]
#  [-0.41432711]
#  [-0.20442483]
#  [ 0.93346646]
#  [-0.29280474]
#  [-1.69583575]
#  [ 0.37004456]
#  [-1.27603119]
#  [-2.1156403 ]
#  [ 0.85613404]
#  [ 1.35327101]
#  [-1.68478826]
#  [-0.91146408]
#  [ 1.91669292]
#  [-0.48061204]
#  [-0.94460654]
#  [-0.33699469]
#  [-1.1766038 ]
#  [-0.40327962]
#  [ 2.43592486]
#  [ 0.69042172]
#  [ 0.60204181]
#  [-0.90041659]
#  [ 0.07176238]
#  [ 0.27061716]
#  [-1.3644111 ]
#  [-2.57963481]
#  [-0.01661753]
#  [-0.50270701]
#  [-0.50270701]
#  [-0.11604493]
#  [-0.06080748]
#  [-1.25393622]
#  [-0.40327962]
#  [-0.82308417]
#  [-2.41392248]
#  [-1.452791  ]
#  [ 2.61268468]
#  [-0.39223213]
#  [ 0.35899707]
#  [-0.49165953]]
#
#  Target to predict
# -1.9720229530716702

# %%
def create_time_steps(length):
  return list(range(-length, 0))

def show_plot(plot_data, delta, title):
  labels = ['Istoric', 'Valoarea reală din viitor', 'Predicția modelului']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

    plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example')
plt.show()

# %%
def baseline(history):
  return np.mean(history)

show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 0,
           'Model predicție de bază')
plt.show()

BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)

EVALUATION_INTERVAL = 200
EPOCHS = 100

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
for x, y in val_univariate.take(1):
  plot = show_plot([x[0].numpy(), y[0].numpy(),
                    simple_lstm_model.predict(x)[0]], 0, 'Predicție LTSM')
  plot.show()

plt.show()
# Out:
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 7s 24ms/step - loss: 0.7213 - val_loss: 1.2316
# Epoch 2/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7207 - val_loss: 1.2334
# Epoch 3/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7197 - val_loss: 1.2415
# Epoch 4/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7191 - val_loss: 1.2466
# Epoch 5/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7190 - val_loss: 1.2506
# Epoch 6/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7177 - val_loss: 1.2533
# Epoch 7/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7172 - val_loss: 1.2570
# Epoch 8/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7170 - val_loss: 1.2600
# Epoch 9/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7160 - val_loss: 1.2655
# Epoch 10/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7149 - val_loss: 1.2633
# Epoch 11/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7133 - val_loss: 1.2682
# Epoch 12/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7103 - val_loss: 1.2701
# Epoch 13/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7063 - val_loss: 1.2704
# Epoch 14/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7039 - val_loss: 1.2694
# Epoch 15/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7023 - val_loss: 1.2765
# Epoch 16/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.7013 - val_loss: 1.2723
# Epoch 17/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7011 - val_loss: 1.2804
# Epoch 18/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6986 - val_loss: 1.2791
# Epoch 19/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6985 - val_loss: 1.2867
# Epoch 20/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6983 - val_loss: 1.2766
# Epoch 21/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6977 - val_loss: 1.2872
# Epoch 22/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6965 - val_loss: 1.2864
# Epoch 23/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6956 - val_loss: 1.2847
# Epoch 24/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6958 - val_loss: 1.2795
# Epoch 25/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6943 - val_loss: 1.2874
# Epoch 26/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6944 - val_loss: 1.2888
# Epoch 27/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6920 - val_loss: 1.2884
# Epoch 28/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6927 - val_loss: 1.2857
# Epoch 29/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6918 - val_loss: 1.2877
# Epoch 30/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6913 - val_loss: 1.2878
# Epoch 31/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6912 - val_loss: 1.2885
# Epoch 32/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6906 - val_loss: 1.2867
# Epoch 33/100
# 200/200 [==============================] - 6s 30ms/step - loss: 0.6905 - val_loss: 1.2848
# Epoch 34/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6902 - val_loss: 1.2875
# Epoch 35/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6892 - val_loss: 1.2907
# Epoch 36/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6885 - val_loss: 1.2915
# Epoch 37/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6955 - val_loss: 1.2867
# Epoch 38/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6885 - val_loss: 1.2858
# Epoch 39/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6882 - val_loss: 1.2910
# Epoch 40/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6870 - val_loss: 1.2913
# Epoch 41/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6877 - val_loss: 1.2897
# Epoch 42/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6880 - val_loss: 1.2881
# Epoch 43/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6877 - val_loss: 1.2953
# Epoch 44/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6878 - val_loss: 1.2909
# Epoch 45/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6874 - val_loss: 1.2893
# Epoch 46/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6877 - val_loss: 1.2895
# Epoch 47/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6857 - val_loss: 1.2886
# Epoch 48/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6885 - val_loss: 1.2919
# Epoch 49/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6879 - val_loss: 1.2899
# Epoch 50/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6860 - val_loss: 1.2880
# Epoch 51/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6861 - val_loss: 1.2921
# Epoch 52/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6920 - val_loss: 1.2853
# Epoch 53/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6885 - val_loss: 1.2877
# Epoch 54/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6848 - val_loss: 1.2860
# Epoch 55/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6872 - val_loss: 1.2868
# Epoch 56/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6887 - val_loss: 1.2840
# Epoch 57/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6839 - val_loss: 1.2855
# Epoch 58/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6858 - val_loss: 1.2863
# Epoch 59/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6826 - val_loss: 1.2860
# Epoch 60/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6832 - val_loss: 1.2828
# Epoch 61/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6838 - val_loss: 1.2814
# Epoch 62/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6828 - val_loss: 1.2853
# Epoch 63/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6815 - val_loss: 1.2836
# Epoch 64/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6806 - val_loss: 1.2860
# Epoch 65/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6798 - val_loss: 1.2874
# Epoch 66/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6818 - val_loss: 1.2873
# Epoch 67/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6816 - val_loss: 1.2866
# Epoch 68/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6805 - val_loss: 1.2857
# Epoch 69/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6787 - val_loss: 1.2864
# Epoch 70/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6784 - val_loss: 1.2867
# Epoch 71/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6782 - val_loss: 1.2857
# Epoch 72/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6783 - val_loss: 1.2841
# Epoch 73/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6765 - val_loss: 1.2863
# Epoch 74/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6766 - val_loss: 1.2861
# Epoch 75/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6774 - val_loss: 1.2857
# Epoch 76/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6735 - val_loss: 1.2871
# Epoch 77/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6720 - val_loss: 1.2878
# Epoch 78/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6725 - val_loss: 1.2892
# Epoch 79/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6727 - val_loss: 1.2881
# Epoch 80/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6730 - val_loss: 1.2886
# Epoch 81/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6734 - val_loss: 1.2886
# Epoch 82/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6701 - val_loss: 1.2902
# Epoch 83/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6705 - val_loss: 1.2897
# Epoch 84/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6717 - val_loss: 1.2910
# Epoch 85/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6714 - val_loss: 1.2910
# Epoch 86/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6692 - val_loss: 1.2917
# Epoch 87/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6685 - val_loss: 1.2932
# Epoch 88/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6698 - val_loss: 1.2918
# Epoch 89/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6687 - val_loss: 1.2935
# Epoch 90/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6675 - val_loss: 1.2936
# Epoch 91/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6683 - val_loss: 1.2936
# Epoch 92/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6644 - val_loss: 1.2953
# Epoch 93/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6652 - val_loss: 1.2957
# Epoch 94/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6649 - val_loss: 1.2956
# Epoch 95/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6631 - val_loss: 1.2960
# Epoch 96/100
# 200/200 [==============================] - 5s 26ms/step - loss: 0.6639 - val_loss: 1.2951
# Epoch 97/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6644 - val_loss: 1.2965
# Epoch 98/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6615 - val_loss: 1.2981
# Epoch 99/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6621 - val_loss: 1.2982
# Epoch 100/100
# 200/200 [==============================] - 5s 27ms/step - loss: 0.6621 - val_loss: 1.2979

# %%
#Forecast a multivariate time series

features_considered = ['High', 'Log return']
features = df[features_considered]
features.index = df['Date']
features.head()

features.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()

# %%
multi_data_train, multi_data_test = train_test_split(features, train_size=0.7, test_size=0.3, shuffle=False)

dataset = features.values
data_mean = dataset[:len(multi_data_train)].mean(axis=0)
data_std = dataset[:len(multi_data_train)].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

past_history = 100
future_target = 10
STEP = 1
x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   len(multi_data_train), past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               len(multi_data_train), None, past_history,
                                               future_target, STEP,
                                               single_step=True)

print ('Single window of past history : {}'.format(x_train_single[0].shape))

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)

single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Single window of past history : (100, 2)
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 13s 60ms/step - loss: 0.7195 - val_loss: 1.2341
# Epoch 2/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.7168 - val_loss: 1.2358
# Epoch 3/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.7120 - val_loss: 1.2375
# Epoch 4/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.7074 - val_loss: 1.2366
# Epoch 5/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.7014 - val_loss: 1.2405
# Epoch 6/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6958 - val_loss: 1.2406
# Epoch 7/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6882 - val_loss: 1.2458
# Epoch 8/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6797 - val_loss: 1.2464
# Epoch 9/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6713 - val_loss: 1.2428
# Epoch 10/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6634 - val_loss: 1.2465
# Epoch 11/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6544 - val_loss: 1.2481
# Epoch 12/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.6467 - val_loss: 1.2495
# Epoch 13/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.6383 - val_loss: 1.2485
# Epoch 14/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6314 - val_loss: 1.2537
# Epoch 15/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6250 - val_loss: 1.2562
# Epoch 16/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.6203 - val_loss: 1.2566
# Epoch 17/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6142 - val_loss: 1.2567
# Epoch 18/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6087 - val_loss: 1.2597
# Epoch 19/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6037 - val_loss: 1.2597
# Epoch 20/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5974 - val_loss: 1.2707
# Epoch 21/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5911 - val_loss: 1.2729
# Epoch 22/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5858 - val_loss: 1.2733
# Epoch 23/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5797 - val_loss: 1.2800
# Epoch 24/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5754 - val_loss: 1.2773
# Epoch 25/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5686 - val_loss: 1.2765
# Epoch 26/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5621 - val_loss: 1.2874
# Epoch 27/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5552 - val_loss: 1.2775
# Epoch 28/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5480 - val_loss: 1.2885
# Epoch 29/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5423 - val_loss: 1.2906
# Epoch 30/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5352 - val_loss: 1.3035
# Epoch 31/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5296 - val_loss: 1.3042
# Epoch 32/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5212 - val_loss: 1.3070
# Epoch 33/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.5167 - val_loss: 1.3125
# Epoch 34/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5112 - val_loss: 1.3169
# Epoch 35/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5053 - val_loss: 1.3168
# Epoch 36/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5002 - val_loss: 1.3220
# Epoch 37/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.4961 - val_loss: 1.3356
# Epoch 38/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.4893 - val_loss: 1.3305
# Epoch 39/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.4858 - val_loss: 1.3426
# Epoch 40/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.4801 - val_loss: 1.3462
# Epoch 41/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.4758 - val_loss: 1.3441
# Epoch 42/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.4709 - val_loss: 1.3438
# Epoch 43/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.4668 - val_loss: 1.3573
# Epoch 44/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.4618 - val_loss: 1.3568
# Epoch 45/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.4571 - val_loss: 1.3684
# Epoch 46/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.4519 - val_loss: 1.3570
# Epoch 47/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.4471 - val_loss: 1.3644
# Epoch 48/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.4409 - val_loss: 1.3656
# Epoch 49/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.4367 - val_loss: 1.3706
# Epoch 50/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4335 - val_loss: 1.3671
# Epoch 51/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4291 - val_loss: 1.3956
# Epoch 52/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.4252 - val_loss: 1.3829
# Epoch 53/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.4202 - val_loss: 1.4133
# Epoch 54/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.4179 - val_loss: 1.3658
# Epoch 55/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4135 - val_loss: 1.4265
# Epoch 56/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4117 - val_loss: 1.4136
# Epoch 57/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4071 - val_loss: 1.4230
# Epoch 58/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4013 - val_loss: 1.4326
# Epoch 59/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.3993 - val_loss: 1.4404
# Epoch 60/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.3948 - val_loss: 1.4427
# Epoch 61/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.3935 - val_loss: 1.4364
# Epoch 62/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.3889 - val_loss: 1.4671
# Epoch 63/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.3838 - val_loss: 1.4439
# Epoch 64/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.3814 - val_loss: 1.4664
# Epoch 65/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.3773 - val_loss: 1.4697
# Epoch 66/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3732 - val_loss: 1.4916
# Epoch 67/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3772 - val_loss: 1.4902
# Epoch 68/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3756 - val_loss: 1.4835
# Epoch 69/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3661 - val_loss: 1.4631
# Epoch 70/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3633 - val_loss: 1.5055
# Epoch 71/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3590 - val_loss: 1.4732
# Epoch 72/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3564 - val_loss: 1.5217
# Epoch 73/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3535 - val_loss: 1.4776
# Epoch 74/100
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3499 - val_loss: 1.5215
# Epoch 75/100
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3526 - val_loss: 1.5174
# Epoch 76/100
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3488 - val_loss: 1.5330
# Epoch 77/100
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3440 - val_loss: 1.5470
# Epoch 78/100
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3409 - val_loss: 1.5163
# Epoch 79/100
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3403 - val_loss: 1.5100
# Epoch 80/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3357 - val_loss: 1.5293
# Epoch 81/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3307 - val_loss: 1.5332
# Epoch 82/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3314 - val_loss: 1.5420
# Epoch 83/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3312 - val_loss: 1.5472
# Epoch 84/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3235 - val_loss: 1.5520
# Epoch 85/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3218 - val_loss: 1.5511
# Epoch 86/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3226 - val_loss: 1.5510
# Epoch 87/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3168 - val_loss: 1.5655
# Epoch 88/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3155 - val_loss: 1.5596
# Epoch 89/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3111 - val_loss: 1.5608
# Epoch 90/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3132 - val_loss: 1.5753
# Epoch 91/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3066 - val_loss: 1.5942
# Epoch 92/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3071 - val_loss: 1.5645
# Epoch 93/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3037 - val_loss: 1.5921
# Epoch 94/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3040 - val_loss: 1.5796
# Epoch 95/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.2998 - val_loss: 1.6094
# Epoch 96/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3001 - val_loss: 1.5922
# Epoch 97/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.2992 - val_loss: 1.6389
# Epoch 98/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.2964 - val_loss: 1.6300
# Epoch 99/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.2933 - val_loss: 1.6403
# Epoch 100/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.2885 - val_loss: 1.6034

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Pierderea setului de testare')
  plt.plot(epochs, val_loss, 'r', label='Pierderea setului de validare')
  plt.title('Capacitatea de generalizare a modelului')
  plt.legend()

  plt.show()
plt.show()

# %%
plot_train_history(single_step_history,
                   'Predicția într-o singură etapă')

for x, y in val_data_single.take(1):
  plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'Single Step Prediction')
  plot.show()
plt.show()

# %%
#Multi-Step model

future_target = 5
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 len(multi_data_train), past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             len(multi_data_train), None, past_history,
                                             future_target, STEP)

print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (100, 2)
#
#  Target temperature to predict : (5,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='Istoric')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'b',
           label='Valori reale viitoare')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'r',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()
plt.show()

for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))
plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)

multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)

plot_train_history(multi_step_history, 'Capacitatea de învățare a modelului')
# Out:
# (256, 5)
# Epoch 1/100
# 200/200 [==============================] - 25s 111ms/step - loss: 0.7225 - val_loss: 1.2333
# Epoch 2/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.7161 - val_loss: 2.6295
# Epoch 3/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.7033 - val_loss: 1.4090
# Epoch 4/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6875 - val_loss: 1.3605
# Epoch 5/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6765 - val_loss: 77.4547
# Epoch 6/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6695 - val_loss: 1.6199
# Epoch 7/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.6598 - val_loss: 24.4790
# Epoch 8/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.6511 - val_loss: 23.0891
# Epoch 9/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.6426 - val_loss: 7.4537
# Epoch 10/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6343 - val_loss: 10.3031
# Epoch 11/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.6260 - val_loss: 9.7962
# Epoch 12/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.6183 - val_loss: 6.6074
# Epoch 13/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6109 - val_loss: 3.3665
# Epoch 14/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6043 - val_loss: 2.6375
# Epoch 15/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5983 - val_loss: 2.0920
# Epoch 16/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5929 - val_loss: 1.6440
# Epoch 17/100
# 200/200 [==============================] - 22s 111ms/step - loss: 0.5878 - val_loss: 1.4387
# Epoch 18/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.5835 - val_loss: 1.3995
# Epoch 19/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5786 - val_loss: 1.3909
# Epoch 20/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5743 - val_loss: 1.3775
# Epoch 21/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5701 - val_loss: 1.3784
# Epoch 22/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5661 - val_loss: 1.3650
# Epoch 23/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5621 - val_loss: 1.3842
# Epoch 24/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.5574 - val_loss: 1.3786
# Epoch 25/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5525 - val_loss: 1.3843
# Epoch 26/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5481 - val_loss: 1.4216
# Epoch 27/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5435 - val_loss: 1.4090
# Epoch 28/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.5395 - val_loss: 1.4558
# Epoch 29/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.5355 - val_loss: 1.4592
# Epoch 30/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5318 - val_loss: 1.4635
# Epoch 31/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5279 - val_loss: 1.4534
# Epoch 32/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5243 - val_loss: 1.5120
# Epoch 33/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5201 - val_loss: 1.5325
# Epoch 34/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5164 - val_loss: 1.4679
# Epoch 35/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.5125 - val_loss: 1.4668
# Epoch 36/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5087 - val_loss: 1.4768
# Epoch 37/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5052 - val_loss: 1.4744
# Epoch 38/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5017 - val_loss: 1.4834
# Epoch 39/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4982 - val_loss: 1.4826
# Epoch 40/100
# 200/200 [==============================] - 20s 98ms/step - loss: 0.4946 - val_loss: 1.4977
# Epoch 41/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4911 - val_loss: 1.5100
# Epoch 42/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4886 - val_loss: 1.5023
# Epoch 43/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4854 - val_loss: 1.5118
# Epoch 44/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4823 - val_loss: 1.5346
# Epoch 45/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4797 - val_loss: 1.5512
# Epoch 46/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4772 - val_loss: 1.5539
# Epoch 47/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4752 - val_loss: 1.5638
# Epoch 48/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4721 - val_loss: 1.5787
# Epoch 49/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4696 - val_loss: 1.5963
# Epoch 50/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4678 - val_loss: 1.5689
# Epoch 51/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4649 - val_loss: 1.6082
# Epoch 52/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4627 - val_loss: 1.5812
# Epoch 53/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4606 - val_loss: 1.6300
# Epoch 54/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4584 - val_loss: 1.5635
# Epoch 55/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4554 - val_loss: 1.6120
# Epoch 56/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4525 - val_loss: 1.5829
# Epoch 57/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4504 - val_loss: 1.5569
# Epoch 58/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4475 - val_loss: 1.5766
# Epoch 59/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4451 - val_loss: 1.5551
# Epoch 60/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4416 - val_loss: 1.5719
# Epoch 61/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4390 - val_loss: 1.5771
# Epoch 62/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4357 - val_loss: 1.5652
# Epoch 63/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4326 - val_loss: 1.5804
# Epoch 64/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4300 - val_loss: 1.5670
# Epoch 65/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4269 - val_loss: 1.5960
# Epoch 66/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4231 - val_loss: 1.5989
# Epoch 67/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4206 - val_loss: 1.5630
# Epoch 68/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4173 - val_loss: 1.5677
# Epoch 69/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4143 - val_loss: 1.6077
# Epoch 70/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4115 - val_loss: 1.6156
# Epoch 71/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4085 - val_loss: 1.6009
# Epoch 72/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4053 - val_loss: 1.5677
# Epoch 73/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.4023 - val_loss: 1.5972
# Epoch 74/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3992 - val_loss: 1.5929
# Epoch 75/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3956 - val_loss: 1.6148
# Epoch 76/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.3931 - val_loss: 1.5956
# Epoch 77/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3891 - val_loss: 1.5696
# Epoch 78/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3863 - val_loss: 1.6331
# Epoch 79/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.3834 - val_loss: 1.6024
# Epoch 80/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3802 - val_loss: 1.5708
# Epoch 81/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3774 - val_loss: 1.5577
# Epoch 82/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.3741 - val_loss: 1.5585
# Epoch 83/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.3714 - val_loss: 1.5781
# Epoch 84/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3682 - val_loss: 1.5653
# Epoch 85/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3647 - val_loss: 1.5801
# Epoch 86/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3616 - val_loss: 1.5633
# Epoch 87/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3581 - val_loss: 1.5497
# Epoch 88/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3551 - val_loss: 1.5438
# Epoch 89/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3524 - val_loss: 1.5498
# Epoch 90/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3486 - val_loss: 1.5447
# Epoch 91/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3461 - val_loss: 1.5373
# Epoch 92/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3428 - val_loss: 1.5310
# Epoch 93/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3398 - val_loss: 1.5306
# Epoch 94/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3370 - val_loss: 1.5564
# Epoch 95/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3340 - val_loss: 1.5587
# Epoch 96/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3314 - val_loss: 1.5377
# Epoch 97/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3288 - val_loss: 1.5467
# Epoch 98/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3258 - val_loss: 1.5414
# Epoch 99/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3231 - val_loss: 1.5131
# Epoch 100/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3210 - val_loss: 1.5235

# %%
#Predict a multi-step future

predicted=(multi_step_model.predict(x)[0])*data_std[1]+data_mean[1]
history=(x[0])*data_std[1]+data_mean[1]
true_future=(y[0])*data_std[1]+data_mean[1]

for x, y in val_data_multi.take(1):
  multi_step_plot(history, true_future, predicted)


from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(true_future, predicted))
print(rmse)
# Out:
# 0.015677271298127727
