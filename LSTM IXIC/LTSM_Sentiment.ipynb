# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf
df = pd.read_excel('^IXIC.xlsx')

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)
TRAIN_SPLIT = 0.7
tf.random.set_seed(13)

# %%
#Predictia seriei de timp univariate
uni_data = df['Log return']
uni_data.index = df['Date']
print(uni_data.head())

uni_data.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()
# Out:
# Date
# 2012-01-03    0.0000
# 2012-01-04   -0.0001
# 2012-01-05    0.0081
# 2012-01-06    0.0016
# 2012-01-09    0.0009
# Name: Log return, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

uni_data_train, uni_data_test = train_test_split(uni_data, train_size=0.7, test_size=0.3, shuffle=False)
uni_data = uni_data.values

# %%
uni_train_mean = uni_data_train.mean()
uni_train_std = uni_data_train.std()

uni_data = (uni_data-uni_train_mean)/uni_train_std

univariate_past_history = 100
univariate_future_target = 10

x_train_uni, y_train_uni = univariate_data(uni_data, 0, len(uni_data_train),
                                           univariate_past_history,
                                           univariate_future_target)
x_val_uni, y_val_uni = univariate_data(uni_data, len(uni_data_train), None,
                                       univariate_past_history,
                                       univariate_future_target)

print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-0.07185497]
#  [-0.08290246]
#  [ 0.82299158]
#  [ 0.10490484]
#  [ 0.02757242]
#  [ 0.9887039 ]
#  [ 0.27061716]
#  [ 0.49156693]
#  [-0.64632436]
#  [ 0.63518428]
#  [ 1.59631576]
#  [ 0.66832674]
#  [-0.1381399 ]
#  [-0.17128237]
#  [ 0.02757242]
#  [ 1.1765112 ]
#  [-0.58003943]
#  [ 0.37004456]
#  [-0.24861478]
#  [ 0.00547745]
#  [ 1.2759386 ]
#  [ 0.37004456]
#  [ 1.69574315]
#  [-0.21547232]
#  [ 0.00547745]
#  [ 0.37004456]
#  [ 0.35899707]
#  [-0.95565403]
#  [ 0.96660892]
#  [-0.04976   ]
#  [-0.67946683]
#  [ 1.58526827]
#  [-0.37013716]
#  [-0.19337734]
#  [-0.64632436]
#  [ 0.82299158]
#  [ 0.18223726]
#  [ 0.01652493]
#  [ 0.69042172]
#  [-0.81203669]
#  [ 0.74565916]
#  [-0.54689697]
#  [-1.03298645]
#  [-1.58536086]
#  [ 0.88927651]
#  [ 1.23174864]
#  [ 0.59099432]
#  [-0.24861478]
#  [ 1.99402533]
#  [-0.03871251]
#  [ 0.49156693]
#  [-0.11604493]
#  [ 0.75670665]
#  [-0.22651981]
#  [-0.02766502]
#  [-0.50270701]
#  [ 0.09385735]
#  [ 1.88355045]
#  [-0.14918739]
#  [-0.6131819 ]
#  [-0.41432711]
#  [-0.20442483]
#  [ 0.93346646]
#  [-0.29280474]
#  [-1.69583575]
#  [ 0.37004456]
#  [-1.27603119]
#  [-2.1156403 ]
#  [ 0.85613404]
#  [ 1.35327101]
#  [-1.68478826]
#  [-0.91146408]
#  [ 1.91669292]
#  [-0.48061204]
#  [-0.94460654]
#  [-0.33699469]
#  [-1.1766038 ]
#  [-0.40327962]
#  [ 2.43592486]
#  [ 0.69042172]
#  [ 0.60204181]
#  [-0.90041659]
#  [ 0.07176238]
#  [ 0.27061716]
#  [-1.3644111 ]
#  [-2.57963481]
#  [-0.01661753]
#  [-0.50270701]
#  [-0.50270701]
#  [-0.11604493]
#  [-0.06080748]
#  [-1.25393622]
#  [-0.40327962]
#  [-0.82308417]
#  [-2.41392248]
#  [-1.452791  ]
#  [ 2.61268468]
#  [-0.39223213]
#  [ 0.35899707]
#  [-0.49165953]]
#
#  Target to predict
# -1.9720229530716702

# %%
def create_time_steps(length):
  return list(range(-length, 0))

def show_plot(plot_data, delta, title):
  labels = ['Istoric', 'Valoarea reală din viitor', 'Predicția modelului']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

    plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example')
plt.show()

# %%
def baseline(history):
  return np.mean(history)

show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 0,
           'Model predicție de bază')
plt.show()

BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)

EVALUATION_INTERVAL = 200
EPOCHS = 100

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
for x, y in val_univariate.take(1):
  plot = show_plot([x[0].numpy(), y[0].numpy(),
                    simple_lstm_model.predict(x)[0]], 0, 'Predicție LTSM')
  plot.show()

plt.show()
# Out:
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 8s 25ms/step - loss: 0.7213 - val_loss: 1.2316
# Epoch 2/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7207 - val_loss: 1.2334
# Epoch 3/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7197 - val_loss: 1.2415
# Epoch 4/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7191 - val_loss: 1.2466
# Epoch 5/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7190 - val_loss: 1.2506
# Epoch 6/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7177 - val_loss: 1.2533
# Epoch 7/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7172 - val_loss: 1.2570
# Epoch 8/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7170 - val_loss: 1.2600
# Epoch 9/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7160 - val_loss: 1.2655
# Epoch 10/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7149 - val_loss: 1.2633
# Epoch 11/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7133 - val_loss: 1.2682
# Epoch 12/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7103 - val_loss: 1.2701
# Epoch 13/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7063 - val_loss: 1.2704
# Epoch 14/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7039 - val_loss: 1.2694
# Epoch 15/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7023 - val_loss: 1.2765
# Epoch 16/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7013 - val_loss: 1.2723
# Epoch 17/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7011 - val_loss: 1.2804
# Epoch 18/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6986 - val_loss: 1.2791
# Epoch 19/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6985 - val_loss: 1.2867
# Epoch 20/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6983 - val_loss: 1.2766
# Epoch 21/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6977 - val_loss: 1.2872
# Epoch 22/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6965 - val_loss: 1.2864
# Epoch 23/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6956 - val_loss: 1.2847
# Epoch 24/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6958 - val_loss: 1.2795
# Epoch 25/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6943 - val_loss: 1.2874
# Epoch 26/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6944 - val_loss: 1.2888
# Epoch 27/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6920 - val_loss: 1.2884
# Epoch 28/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6927 - val_loss: 1.2857
# Epoch 29/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6918 - val_loss: 1.2877
# Epoch 30/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6913 - val_loss: 1.2878
# Epoch 31/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6912 - val_loss: 1.2885
# Epoch 32/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6906 - val_loss: 1.2867
# Epoch 33/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6905 - val_loss: 1.2848
# Epoch 34/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6902 - val_loss: 1.2875
# Epoch 35/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6892 - val_loss: 1.2907
# Epoch 36/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6885 - val_loss: 1.2915
# Epoch 37/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6955 - val_loss: 1.2867
# Epoch 38/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6885 - val_loss: 1.2858
# Epoch 39/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6882 - val_loss: 1.2910
# Epoch 40/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6870 - val_loss: 1.2913
# Epoch 41/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6877 - val_loss: 1.2897
# Epoch 42/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6880 - val_loss: 1.2881
# Epoch 43/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6877 - val_loss: 1.2953
# Epoch 44/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.6878 - val_loss: 1.2909
# Epoch 45/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6874 - val_loss: 1.2893
# Epoch 46/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6877 - val_loss: 1.2895
# Epoch 47/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6857 - val_loss: 1.2886
# Epoch 48/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6885 - val_loss: 1.2919
# Epoch 49/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6879 - val_loss: 1.2899
# Epoch 50/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6860 - val_loss: 1.2880
# Epoch 51/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6861 - val_loss: 1.2921
# Epoch 52/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6920 - val_loss: 1.2853
# Epoch 53/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6885 - val_loss: 1.2877
# Epoch 54/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6848 - val_loss: 1.2860
# Epoch 55/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6872 - val_loss: 1.2868
# Epoch 56/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6887 - val_loss: 1.2840
# Epoch 57/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6839 - val_loss: 1.2855
# Epoch 58/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6858 - val_loss: 1.2863
# Epoch 59/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6826 - val_loss: 1.2860
# Epoch 60/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6832 - val_loss: 1.2828
# Epoch 61/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6838 - val_loss: 1.2814
# Epoch 62/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6828 - val_loss: 1.2853
# Epoch 63/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6815 - val_loss: 1.2836
# Epoch 64/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6806 - val_loss: 1.2860
# Epoch 65/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6798 - val_loss: 1.2874
# Epoch 66/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6818 - val_loss: 1.2873
# Epoch 67/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6816 - val_loss: 1.2866
# Epoch 68/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6805 - val_loss: 1.2857
# Epoch 69/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6787 - val_loss: 1.2864
# Epoch 70/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6784 - val_loss: 1.2867
# Epoch 71/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6782 - val_loss: 1.2857
# Epoch 72/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6783 - val_loss: 1.2841
# Epoch 73/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6765 - val_loss: 1.2863
# Epoch 74/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6766 - val_loss: 1.2861
# Epoch 75/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6774 - val_loss: 1.2857
# Epoch 76/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6735 - val_loss: 1.2871
# Epoch 77/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6720 - val_loss: 1.2878
# Epoch 78/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6725 - val_loss: 1.2892
# Epoch 79/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6727 - val_loss: 1.2881
# Epoch 80/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6730 - val_loss: 1.2886
# Epoch 81/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6734 - val_loss: 1.2886
# Epoch 82/100
# 200/200 [==============================] - 5s 22ms/step - loss: 0.6701 - val_loss: 1.2902
# Epoch 83/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6705 - val_loss: 1.2897
# Epoch 84/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6717 - val_loss: 1.2910
# Epoch 85/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6714 - val_loss: 1.2910
# Epoch 86/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6692 - val_loss: 1.2917
# Epoch 87/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6685 - val_loss: 1.2932
# Epoch 88/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6698 - val_loss: 1.2918
# Epoch 89/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6687 - val_loss: 1.2935
# Epoch 90/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6675 - val_loss: 1.2936
# Epoch 91/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6683 - val_loss: 1.2936
# Epoch 92/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6644 - val_loss: 1.2953
# Epoch 93/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.6652 - val_loss: 1.2957
# Epoch 94/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6649 - val_loss: 1.2956
# Epoch 95/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6631 - val_loss: 1.2960
# Epoch 96/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6639 - val_loss: 1.2951
# Epoch 97/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6644 - val_loss: 1.2965
# Epoch 98/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6615 - val_loss: 1.2981
# Epoch 99/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6621 - val_loss: 1.2982
# Epoch 100/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6621 - val_loss: 1.2979

# %%
#Forecast a multivariate time series

features_considered = ['Sentiment', 'Log return']
features = df[features_considered]
features.index = df['Date']
features.head()

features.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()

# %%
multi_data_train, multi_data_test = train_test_split(features, train_size=0.7, test_size=0.3, shuffle=False)

dataset = features.values
data_mean = dataset[:len(multi_data_train)].mean(axis=0)
data_std = dataset[:len(multi_data_train)].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

past_history = 100
future_target = 10
STEP = 1
x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   len(multi_data_train), past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               len(multi_data_train), None, past_history,
                                               future_target, STEP,
                                               single_step=True)

print ('Single window of past history : {}'.format(x_train_single[0].shape))

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)

single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Single window of past history : (100, 2)
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 12s 53ms/step - loss: 0.7179 - val_loss: 1.2396
# Epoch 2/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.7135 - val_loss: 1.2468
# Epoch 3/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.7056 - val_loss: 1.2539
# Epoch 4/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.6988 - val_loss: 1.2686
# Epoch 5/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6908 - val_loss: 1.2855
# Epoch 6/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6847 - val_loss: 1.2993
# Epoch 7/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6771 - val_loss: 1.3221
# Epoch 8/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.6702 - val_loss: 1.3336
# Epoch 9/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6645 - val_loss: 1.3414
# Epoch 10/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6593 - val_loss: 1.3400
# Epoch 11/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6528 - val_loss: 1.3511
# Epoch 12/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.6457 - val_loss: 1.3432
# Epoch 13/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.6390 - val_loss: 1.3548
# Epoch 14/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6339 - val_loss: 1.3559
# Epoch 15/100
# 200/200 [==============================] - 9s 48ms/step - loss: 0.6268 - val_loss: 1.3536
# Epoch 16/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6216 - val_loss: 1.3561
# Epoch 17/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.6151 - val_loss: 1.3869
# Epoch 18/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6087 - val_loss: 1.3614
# Epoch 19/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.6036 - val_loss: 1.3733
# Epoch 20/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.5970 - val_loss: 1.3523
# Epoch 21/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.5923 - val_loss: 1.3602
# Epoch 22/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.5869 - val_loss: 1.3640
# Epoch 23/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.5792 - val_loss: 1.3856
# Epoch 24/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.5782 - val_loss: 1.3830
# Epoch 25/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.5716 - val_loss: 1.3806
# Epoch 26/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5682 - val_loss: 1.3801
# Epoch 27/100
# 200/200 [==============================] - 11s 53ms/step - loss: 0.5639 - val_loss: 1.3787
# Epoch 28/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5608 - val_loss: 1.3867
# Epoch 29/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5516 - val_loss: 1.3939
# Epoch 30/100
# 200/200 [==============================] - 11s 53ms/step - loss: 0.5467 - val_loss: 1.3878
# Epoch 31/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5429 - val_loss: 1.3992
# Epoch 32/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5429 - val_loss: 1.3840
# Epoch 33/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5364 - val_loss: 1.3788
# Epoch 34/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.5303 - val_loss: 1.4007
# Epoch 35/100
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5276 - val_loss: 1.3982
# Epoch 36/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.5207 - val_loss: 1.3763
# Epoch 37/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.5195 - val_loss: 1.4084
# Epoch 38/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.5097 - val_loss: 1.3949
# Epoch 39/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5118 - val_loss: 1.4055
# Epoch 40/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5129 - val_loss: 1.4045
# Epoch 41/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.5038 - val_loss: 1.4154
# Epoch 42/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4984 - val_loss: 1.4179
# Epoch 43/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4982 - val_loss: 1.4079
# Epoch 44/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4923 - val_loss: 1.4089
# Epoch 45/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.4876 - val_loss: 1.3976
# Epoch 46/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.4854 - val_loss: 1.4015
# Epoch 47/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.4798 - val_loss: 1.3935
# Epoch 48/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.4770 - val_loss: 1.4205
# Epoch 49/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.4710 - val_loss: 1.4185
# Epoch 50/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.4658 - val_loss: 1.3997
# Epoch 51/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.4644 - val_loss: 1.4221
# Epoch 52/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.4571 - val_loss: 1.4162
# Epoch 53/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.4542 - val_loss: 1.4265
# Epoch 54/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.4593 - val_loss: 1.4055
# Epoch 55/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.4494 - val_loss: 1.4108
# Epoch 56/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4458 - val_loss: 1.4076
# Epoch 57/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4449 - val_loss: 1.4212
# Epoch 58/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4376 - val_loss: 1.4026
# Epoch 59/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4401 - val_loss: 1.4175
# Epoch 60/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4388 - val_loss: 1.4098
# Epoch 61/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4299 - val_loss: 1.4090
# Epoch 62/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4302 - val_loss: 1.4152
# Epoch 63/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4226 - val_loss: 1.4156
# Epoch 64/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4357 - val_loss: 1.4229
# Epoch 65/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4243 - val_loss: 1.4321
# Epoch 66/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4154 - val_loss: 1.4225
# Epoch 67/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4146 - val_loss: 1.4268
# Epoch 68/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4251 - val_loss: 1.4377
# Epoch 69/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.4211 - val_loss: 1.4211
# Epoch 70/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4413 - val_loss: 1.4198
# Epoch 71/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4153 - val_loss: 1.4217
# Epoch 72/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4032 - val_loss: 1.4198
# Epoch 73/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3951 - val_loss: 1.4397
# Epoch 74/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3974 - val_loss: 1.4272
# Epoch 75/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3925 - val_loss: 1.4580
# Epoch 76/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3886 - val_loss: 1.4381
# Epoch 77/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3964 - val_loss: 1.4476
# Epoch 78/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4110 - val_loss: 1.4313
# Epoch 79/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3915 - val_loss: 1.4552
# Epoch 80/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3837 - val_loss: 1.4548
# Epoch 81/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3744 - val_loss: 1.4641
# Epoch 82/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3798 - val_loss: 1.4518
# Epoch 83/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3685 - val_loss: 1.4526
# Epoch 84/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3675 - val_loss: 1.4383
# Epoch 85/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3684 - val_loss: 1.4601
# Epoch 86/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3636 - val_loss: 1.4576
# Epoch 87/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3596 - val_loss: 1.4688
# Epoch 88/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3579 - val_loss: 1.4611
# Epoch 89/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3553 - val_loss: 1.4769
# Epoch 90/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3495 - val_loss: 1.4699
# Epoch 91/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3528 - val_loss: 1.4734
# Epoch 92/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3478 - val_loss: 1.4781
# Epoch 93/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3427 - val_loss: 1.4802
# Epoch 94/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3620 - val_loss: 1.4958
# Epoch 95/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3487 - val_loss: 1.4851
# Epoch 96/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3499 - val_loss: 1.4833
# Epoch 97/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3526 - val_loss: 1.5046
# Epoch 98/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3378 - val_loss: 1.4983
# Epoch 99/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3338 - val_loss: 1.4836
# Epoch 100/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.3330 - val_loss: 1.4816

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Pierderea setului de testare')
  plt.plot(epochs, val_loss, 'r', label='Pierderea setului de validare')
  plt.title('Capacitatea de generalizare a modelului')
  plt.legend()

  plt.show()
plt.show()

# %%
plot_train_history(single_step_history,
                   'Predicția într-o singură etapă')

for x, y in val_data_single.take(1):
  plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'Single Step Prediction')
  plot.show()
plt.show()

# %%
#Multi-Step model

future_target = 5
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 len(multi_data_train), past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             len(multi_data_train), None, past_history,
                                             future_target, STEP)

print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (100, 2)
#
#  Target temperature to predict : (5,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='Istoric')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'b',
           label='Valori reale viitoare')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'r',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()
plt.show()

for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))
plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)

multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)

plot_train_history(multi_step_history, 'Capacitatea de învățare a modelului')
# Out:
# (256, 5)
# Epoch 1/100
# 200/200 [==============================] - 22s 95ms/step - loss: 0.7221 - val_loss: 1.2314
# Epoch 2/100
# 200/200 [==============================] - 18s 88ms/step - loss: 0.7160 - val_loss: 102403.1719
# Epoch 3/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.7016 - val_loss: 111874.0312
# Epoch 4/100
# 200/200 [==============================] - 17s 83ms/step - loss: 66.8606 - val_loss: 12198395904.0000
# Epoch 5/100
# 200/200 [==============================] - 17s 85ms/step - loss: 82745.4297 - val_loss: 30.6069
# Epoch 6/100
# 200/200 [==============================] - 18s 88ms/step - loss: 48140820.0000 - val_loss: 20.7188
# Epoch 7/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.6649 - val_loss: 4.2641
# Epoch 8/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.6557 - val_loss: 1.8925
# Epoch 9/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.6569 - val_loss: 1.5049
# Epoch 10/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.6408 - val_loss: 1.5149
# Epoch 11/100
# 200/200 [==============================] - 22s 111ms/step - loss: 0.6341 - val_loss: 1.5319
# Epoch 12/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.6292 - val_loss: 16.8709
# Epoch 13/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.6236 - val_loss: 700875538432.0000
# Epoch 14/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.6187 - val_loss: 2.3318
# Epoch 15/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.6132 - val_loss: 711374077952.0000
# Epoch 16/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.6077 - val_loss: 944094642176.0000
# Epoch 17/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.6028 - val_loss: 759927734272.0000
# Epoch 18/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5992 - val_loss: 5276119040.0000
# Epoch 19/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.5949 - val_loss: 907.2286
# Epoch 20/100
# 200/200 [==============================] - 19s 93ms/step - loss: 18430748.0000 - val_loss: 453.5854
# Epoch 21/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.5892 - val_loss: 138.0600
# Epoch 22/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.5858 - val_loss: 28.2946
# Epoch 23/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.5823 - val_loss: 8.9394
# Epoch 24/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.5773 - val_loss: 7.6030
# Epoch 25/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5738 - val_loss: 9.7528
# Epoch 26/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.5704 - val_loss: 7.7113
# Epoch 27/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.5661 - val_loss: 1.5868
# Epoch 28/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.5624 - val_loss: 1.5552
# Epoch 29/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5590 - val_loss: 1.5429
# Epoch 30/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.5555 - val_loss: 1.5427
# Epoch 31/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.5521 - val_loss: 1.5254
# Epoch 32/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.5494 - val_loss: 1.5234
# Epoch 33/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.5452 - val_loss: 1.5309
# Epoch 34/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.5426 - val_loss: 1.5308
# Epoch 35/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.5383 - val_loss: 1.5224
# Epoch 36/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5352 - val_loss: 1.5309
# Epoch 37/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.5319 - val_loss: 1.5235
# Epoch 38/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.5285 - val_loss: 1.5247
# Epoch 39/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5253 - val_loss: 1.5376
# Epoch 40/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.5223 - val_loss: 1.5381
# Epoch 41/100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.5183 - val_loss: 1.5516
# Epoch 42/100
# 200/200 [==============================] - 22s 111ms/step - loss: 0.5160 - val_loss: 1.5602
# Epoch 43/100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.5122 - val_loss: 1.5632
# Epoch 44/100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.5083 - val_loss: 1.5684
# Epoch 45/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.5049 - val_loss: 1.5976
# Epoch 46/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.5009 - val_loss: 1.6134
# Epoch 47/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4973 - val_loss: 1.6282
# Epoch 48/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4937 - val_loss: 1.5950
# Epoch 49/100
# 200/200 [==============================] - 19s 97ms/step - loss: 0.4901 - val_loss: 1.5931
# Epoch 50/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.4867 - val_loss: 1.6100
# Epoch 51/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.4827 - val_loss: 1.6115
# Epoch 52/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.4787 - val_loss: 1.6252
# Epoch 53/100
# 200/200 [==============================] - 20s 98ms/step - loss: 0.4756 - val_loss: 1.6036
# Epoch 54/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4715 - val_loss: 1.6333
# Epoch 55/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4683 - val_loss: 1.6063
# Epoch 56/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4646 - val_loss: 1.6042
# Epoch 57/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4608 - val_loss: 1.5419
# Epoch 58/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4566 - val_loss: 1.5671
# Epoch 59/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4532 - val_loss: 1.5794
# Epoch 60/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4493 - val_loss: 1.5859
# Epoch 61/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.4456 - val_loss: 1.5674
# Epoch 62/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4419 - val_loss: 1.5887
# Epoch 63/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.4379 - val_loss: 1.5668
# Epoch 64/100
# 200/200 [==============================] - 20s 98ms/step - loss: 0.4339 - val_loss: 1.5560
# Epoch 65/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.4305 - val_loss: 1.5596
# Epoch 66/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.4269 - val_loss: 1.5487
# Epoch 67/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.4229 - val_loss: 1.5684
# Epoch 68/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.4194 - val_loss: 1.5706
# Epoch 69/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.4158 - val_loss: 1.5647
# Epoch 70/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.4121 - val_loss: 1.5548
# Epoch 71/100
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4092 - val_loss: 1.5595
# Epoch 72/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.4052 - val_loss: 1.5506
# Epoch 73/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.4020 - val_loss: 1.5623
# Epoch 74/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.3982 - val_loss: 1.5640
# Epoch 75/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.3942 - val_loss: 1.5553
# Epoch 76/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.3912 - val_loss: 1.5458
# Epoch 77/100
# 200/200 [==============================] - 17s 87ms/step - loss: 0.3867 - val_loss: 1.5596
# Epoch 78/100
# 200/200 [==============================] - 19s 97ms/step - loss: 0.3835 - val_loss: 1.5543
# Epoch 79/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.3801 - val_loss: 1.5491
# Epoch 80/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.3765 - val_loss: 1.5405
# Epoch 81/100
# 200/200 [==============================] - 20s 100ms/step - loss: 0.3726 - val_loss: 1.5501
# Epoch 82/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.3693 - val_loss: 1.5484
# Epoch 83/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3660 - val_loss: 1.5668
# Epoch 84/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3618 - val_loss: 1.5617
# Epoch 85/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.3593 - val_loss: 1.5618
# Epoch 86/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.3553 - val_loss: 1.5396
# Epoch 87/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.3519 - val_loss: 1.5274
# Epoch 88/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.3487 - val_loss: 1.5373
# Epoch 89/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.3450 - val_loss: 1.5097
# Epoch 90/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.3416 - val_loss: 1.5344
# Epoch 91/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.3387 - val_loss: 1.5147
# Epoch 92/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.3350 - val_loss: 1.5259
# Epoch 93/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.3317 - val_loss: 1.5082
# Epoch 94/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.3285 - val_loss: 1.4985
# Epoch 95/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.3253 - val_loss: 1.5107
# Epoch 96/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.3219 - val_loss: 1.5170
# Epoch 97/100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.3192 - val_loss: 1.5299
# Epoch 98/100
# 200/200 [==============================] - 19s 96ms/step - loss: 0.3151 - val_loss: 1.5200
# Epoch 99/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.3118 - val_loss: 1.5154
# Epoch 100/100
# 200/200 [==============================] - 19s 93ms/step - loss: 0.3094 - val_loss: 1.5176

# %%
#Predict a multi-step future

predicted=(multi_step_model.predict(x)[0])*data_std[1]+data_mean[1]
history=(x[0])*data_std[1]+data_mean[1]
true_future=(y[0])*data_std[1]+data_mean[1]

for x, y in val_data_multi.take(1):
  multi_step_plot(history, true_future, predicted)


from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(true_future, predicted))
print(rmse)
# Out:
# 0.008079584430945882
