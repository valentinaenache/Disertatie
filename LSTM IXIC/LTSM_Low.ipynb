# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf
df = pd.read_excel('^IXIC.xlsx')

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)
TRAIN_SPLIT = 0.7
tf.random.set_seed(13)

# %%
#Predictia seriei de timp univariate
uni_data = df['Log return']
uni_data.index = df['Date']
print(uni_data.head())

uni_data.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()
# Out:
# Date
# 2012-01-03    0.0000
# 2012-01-04   -0.0001
# 2012-01-05    0.0081
# 2012-01-06    0.0016
# 2012-01-09    0.0009
# Name: Log return, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

uni_data_train, uni_data_test = train_test_split(uni_data, train_size=0.7, test_size=0.3, shuffle=False)
uni_data = uni_data.values

# %%
uni_train_mean = uni_data_train.mean()
uni_train_std = uni_data_train.std()

uni_data = (uni_data-uni_train_mean)/uni_train_std

univariate_past_history = 100
univariate_future_target = 10

x_train_uni, y_train_uni = univariate_data(uni_data, 0, len(uni_data_train),
                                           univariate_past_history,
                                           univariate_future_target)
x_val_uni, y_val_uni = univariate_data(uni_data, len(uni_data_train), None,
                                       univariate_past_history,
                                       univariate_future_target)

print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-0.07185497]
#  [-0.08290246]
#  [ 0.82299158]
#  [ 0.10490484]
#  [ 0.02757242]
#  [ 0.9887039 ]
#  [ 0.27061716]
#  [ 0.49156693]
#  [-0.64632436]
#  [ 0.63518428]
#  [ 1.59631576]
#  [ 0.66832674]
#  [-0.1381399 ]
#  [-0.17128237]
#  [ 0.02757242]
#  [ 1.1765112 ]
#  [-0.58003943]
#  [ 0.37004456]
#  [-0.24861478]
#  [ 0.00547745]
#  [ 1.2759386 ]
#  [ 0.37004456]
#  [ 1.69574315]
#  [-0.21547232]
#  [ 0.00547745]
#  [ 0.37004456]
#  [ 0.35899707]
#  [-0.95565403]
#  [ 0.96660892]
#  [-0.04976   ]
#  [-0.67946683]
#  [ 1.58526827]
#  [-0.37013716]
#  [-0.19337734]
#  [-0.64632436]
#  [ 0.82299158]
#  [ 0.18223726]
#  [ 0.01652493]
#  [ 0.69042172]
#  [-0.81203669]
#  [ 0.74565916]
#  [-0.54689697]
#  [-1.03298645]
#  [-1.58536086]
#  [ 0.88927651]
#  [ 1.23174864]
#  [ 0.59099432]
#  [-0.24861478]
#  [ 1.99402533]
#  [-0.03871251]
#  [ 0.49156693]
#  [-0.11604493]
#  [ 0.75670665]
#  [-0.22651981]
#  [-0.02766502]
#  [-0.50270701]
#  [ 0.09385735]
#  [ 1.88355045]
#  [-0.14918739]
#  [-0.6131819 ]
#  [-0.41432711]
#  [-0.20442483]
#  [ 0.93346646]
#  [-0.29280474]
#  [-1.69583575]
#  [ 0.37004456]
#  [-1.27603119]
#  [-2.1156403 ]
#  [ 0.85613404]
#  [ 1.35327101]
#  [-1.68478826]
#  [-0.91146408]
#  [ 1.91669292]
#  [-0.48061204]
#  [-0.94460654]
#  [-0.33699469]
#  [-1.1766038 ]
#  [-0.40327962]
#  [ 2.43592486]
#  [ 0.69042172]
#  [ 0.60204181]
#  [-0.90041659]
#  [ 0.07176238]
#  [ 0.27061716]
#  [-1.3644111 ]
#  [-2.57963481]
#  [-0.01661753]
#  [-0.50270701]
#  [-0.50270701]
#  [-0.11604493]
#  [-0.06080748]
#  [-1.25393622]
#  [-0.40327962]
#  [-0.82308417]
#  [-2.41392248]
#  [-1.452791  ]
#  [ 2.61268468]
#  [-0.39223213]
#  [ 0.35899707]
#  [-0.49165953]]
#
#  Target to predict
# -1.9720229530716702

# %%
def create_time_steps(length):
  return list(range(-length, 0))

def show_plot(plot_data, delta, title):
  labels = ['Istoric', 'Valoarea reală din viitor', 'Predicția modelului']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

    plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example')
plt.show()

# %%
def baseline(history):
  return np.mean(history)

show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 0,
           'Model predicție de bază')
plt.show()

BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)

EVALUATION_INTERVAL = 200
EPOCHS = 100

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
for x, y in val_univariate.take(1):
  plot = show_plot([x[0].numpy(), y[0].numpy(),
                    simple_lstm_model.predict(x)[0]], 0, 'Predicție LTSM')
  plot.show()

plt.show()
# Out:
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 12s 47ms/step - loss: 0.7213 - val_loss: 1.2316
# Epoch 2/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.7207 - val_loss: 1.2334
# Epoch 3/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.7197 - val_loss: 1.2415
# Epoch 4/100
# 200/200 [==============================] - 14s 71ms/step - loss: 0.7191 - val_loss: 1.2466
# Epoch 5/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.7190 - val_loss: 1.2506
# Epoch 6/100
# 200/200 [==============================] - 14s 67ms/step - loss: 0.7177 - val_loss: 1.2533
# Epoch 7/100
# 200/200 [==============================] - 13s 62ms/step - loss: 0.7172 - val_loss: 1.2570
# Epoch 8/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.7170 - val_loss: 1.2600
# Epoch 9/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.7160 - val_loss: 1.2655
# Epoch 10/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.7149 - val_loss: 1.2633
# Epoch 11/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.7133 - val_loss: 1.2682
# Epoch 12/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.7103 - val_loss: 1.2701
# Epoch 13/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.7063 - val_loss: 1.2704
# Epoch 14/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.7039 - val_loss: 1.2694
# Epoch 15/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.7023 - val_loss: 1.2765
# Epoch 16/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.7013 - val_loss: 1.2723
# Epoch 17/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.7011 - val_loss: 1.2804
# Epoch 18/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6986 - val_loss: 1.2791
# Epoch 19/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6985 - val_loss: 1.2867
# Epoch 20/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6983 - val_loss: 1.2766
# Epoch 21/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6977 - val_loss: 1.2872
# Epoch 22/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6965 - val_loss: 1.2864
# Epoch 23/100
# 200/200 [==============================] - 14s 67ms/step - loss: 0.6956 - val_loss: 1.2847
# Epoch 24/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6958 - val_loss: 1.2795
# Epoch 25/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6943 - val_loss: 1.2874
# Epoch 26/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6944 - val_loss: 1.2888
# Epoch 27/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6920 - val_loss: 1.2884
# Epoch 28/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6927 - val_loss: 1.2857
# Epoch 29/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6918 - val_loss: 1.2877
# Epoch 30/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6913 - val_loss: 1.2878
# Epoch 31/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6912 - val_loss: 1.2885
# Epoch 32/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6906 - val_loss: 1.2867
# Epoch 33/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6905 - val_loss: 1.2848
# Epoch 34/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6902 - val_loss: 1.2875
# Epoch 35/100
# 200/200 [==============================] - 14s 71ms/step - loss: 0.6892 - val_loss: 1.2907
# Epoch 36/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6885 - val_loss: 1.2915
# Epoch 37/100
# 200/200 [==============================] - 14s 70ms/step - loss: 0.6955 - val_loss: 1.2867
# Epoch 38/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6885 - val_loss: 1.2858
# Epoch 39/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6882 - val_loss: 1.2910
# Epoch 40/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6870 - val_loss: 1.2913
# Epoch 41/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6877 - val_loss: 1.2897
# Epoch 42/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6880 - val_loss: 1.2881
# Epoch 43/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6877 - val_loss: 1.2953
# Epoch 44/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6878 - val_loss: 1.2909
# Epoch 45/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6874 - val_loss: 1.2893
# Epoch 46/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6877 - val_loss: 1.2895
# Epoch 47/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6857 - val_loss: 1.2886
# Epoch 48/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6885 - val_loss: 1.2919
# Epoch 49/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6879 - val_loss: 1.2899
# Epoch 50/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6860 - val_loss: 1.2880
# Epoch 51/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6861 - val_loss: 1.2921
# Epoch 52/100
# 200/200 [==============================] - 14s 68ms/step - loss: 0.6920 - val_loss: 1.2853
# Epoch 53/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6885 - val_loss: 1.2877
# Epoch 54/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6848 - val_loss: 1.2860
# Epoch 55/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6872 - val_loss: 1.2868
# Epoch 56/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6887 - val_loss: 1.2840
# Epoch 57/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6839 - val_loss: 1.2855
# Epoch 58/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6858 - val_loss: 1.2863
# Epoch 59/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6826 - val_loss: 1.2860
# Epoch 60/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6832 - val_loss: 1.2828
# Epoch 61/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6838 - val_loss: 1.2814
# Epoch 62/100
# 200/200 [==============================] - 14s 70ms/step - loss: 0.6828 - val_loss: 1.2853
# Epoch 63/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6815 - val_loss: 1.2836
# Epoch 64/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6806 - val_loss: 1.2860
# Epoch 65/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6798 - val_loss: 1.2874
# Epoch 66/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6818 - val_loss: 1.2873
# Epoch 67/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6816 - val_loss: 1.2866
# Epoch 68/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6805 - val_loss: 1.2857
# Epoch 69/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6787 - val_loss: 1.2864
# Epoch 70/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6784 - val_loss: 1.2867
# Epoch 71/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6782 - val_loss: 1.2857
# Epoch 72/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6783 - val_loss: 1.2841
# Epoch 73/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.6765 - val_loss: 1.2863
# Epoch 74/100
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6766 - val_loss: 1.2861
# Epoch 75/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6774 - val_loss: 1.2857
# Epoch 76/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6639 - val_loss: 1.2951
# Epoch 97/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.6644 - val_loss: 1.2965
# Epoch 98/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6615 - val_loss: 1.2981
# Epoch 99/100
# 200/200 [==============================] - 8s 41ms/step - loss: 0.6621 - val_loss: 1.2982
# Epoch 100/100
# 200/200 [==============================] - 7s 36ms/step - loss: 0.6621 - val_loss: 1.2979

# %%
#Forecast a multivariate time series

features_considered = ['Low', 'Log return']
features = df[features_considered]
features.index = df['Date']
features.head()

features.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()

# %%
multi_data_train, multi_data_test = train_test_split(features, train_size=0.7, test_size=0.3, shuffle=False)

dataset = features.values
data_mean = dataset[:len(multi_data_train)].mean(axis=0)
data_std = dataset[:len(multi_data_train)].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

past_history = 100
future_target = 10
STEP = 1
x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   len(multi_data_train), past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               len(multi_data_train), None, past_history,
                                               future_target, STEP,
                                               single_step=True)

print ('Single window of past history : {}'.format(x_train_single[0].shape))

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)

single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Single window of past history : (100, 2)
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 59s 152ms/step - loss: 0.7195 - val_loss: 1.2344
# Epoch 2/100
# 200/200 [==============================] - 28s 142ms/step - loss: 0.7168 - val_loss: 1.2349
# Epoch 3/100
# 200/200 [==============================] - 33s 165ms/step - loss: 0.7119 - val_loss: 1.2371
# Epoch 4/100
# 200/200 [==============================] - 35s 173ms/step - loss: 0.7071 - val_loss: 1.2333
# Epoch 5/100
# 200/200 [==============================] - 37s 184ms/step - loss: 0.7015 - val_loss: 1.2392
# Epoch 6/100
# 200/200 [==============================] - 38s 189ms/step - loss: 0.6960 - val_loss: 1.2397
# Epoch 7/100
# 200/200 [==============================] - 35s 176ms/step - loss: 0.6887 - val_loss: 1.2409
# Epoch 8/100
# 200/200 [==============================] - 36s 181ms/step - loss: 0.6805 - val_loss: 1.2407
# Epoch 9/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.6717 - val_loss: 1.2416
# Epoch 10/100
# 200/200 [==============================] - 34s 172ms/step - loss: 0.6643 - val_loss: 1.2505
# Epoch 11/100
# 200/200 [==============================] - 35s 173ms/step - loss: 0.6568 - val_loss: 1.2532
# Epoch 12/100
# 200/200 [==============================] - 35s 173ms/step - loss: 0.6507 - val_loss: 1.2504
# Epoch 13/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.6445 - val_loss: 1.2493
# Epoch 14/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.6390 - val_loss: 1.2534
# Epoch 15/100
# 200/200 [==============================] - 35s 172ms/step - loss: 0.5003 - val_loss: 1.3693
# Epoch 41/100
# 200/200 [==============================] - 35s 176ms/step - loss: 0.4940 - val_loss: 1.3694
# Epoch 42/100
# 200/200 [==============================] - 37s 184ms/step - loss: 0.4891 - val_loss: 1.3760
# Epoch 43/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.4825 - val_loss: 1.3824
# Epoch 44/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.5023 - val_loss: 1.3826
# Epoch 45/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.4795 - val_loss: 1.3926
# Epoch 46/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.4755 - val_loss: 1.3947
# Epoch 47/100
# 200/200 [==============================] - 35s 177ms/step - loss: 0.4705 - val_loss: 1.4037
# Epoch 48/100
# 200/200 [==============================] - 36s 180ms/step - loss: 0.4637 - val_loss: 1.4120
# Epoch 49/100
# 200/200 [==============================] - 35s 175ms/step - loss: 0.4604 - val_loss: 1.4360
# Epoch 50/100
# 200/200 [==============================] - 34s 172ms/step - loss: 0.4585 - val_loss: 1.4059
# Epoch 51/100
# 200/200 [==============================] - 36s 182ms/step - loss: 0.4567 - val_loss: 1.4230
# Epoch 52/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.4527 - val_loss: 1.4427
# Epoch 53/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.4481 - val_loss: 1.4527
# Epoch 54/100
# 200/200 [==============================] - 35s 178ms/step - loss: 0.4438 - val_loss: 1.4389
# Epoch 55/100
# 200/200 [==============================] - 34s 172ms/step - loss: 0.4533 - val_loss: 1.4359
# Epoch 56/100
# 200/200 [==============================] - 36s 181ms/step - loss: 0.4395 - val_loss: 1.4284
# Epoch 57/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.4488 - val_loss: 1.4195
# Epoch 58/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.4326 - val_loss: 1.4499
# Epoch 59/100
# 200/200 [==============================] - 35s 174ms/step - loss: 0.4269 - val_loss: 1.4439
# Epoch 60/100
# 200/200 [==============================] - 35s 177ms/step - loss: 0.4234 - val_loss: 1.4589
# Epoch 61/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.4186 - val_loss: 1.4562
# Epoch 62/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.4180 - val_loss: 1.4674
# Epoch 63/100
# 200/200 [==============================] - 25s 126ms/step - loss: 0.3202 - val_loss: 1.5748

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Pierderea setului de testare')
  plt.plot(epochs, val_loss, 'r', label='Pierderea setului de validare')
  plt.title('Capacitatea de generalizare a modelului')
  plt.legend()

  plt.show()
plt.show()

# %%
plot_train_history(single_step_history,
                   'Predicția într-o singură etapă')

for x, y in val_data_single.take(1):
  plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'Single Step Prediction')
  plot.show()
plt.show()

# %%
#Multi-Step model

future_target = 5
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 len(multi_data_train), past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             len(multi_data_train), None, past_history,
                                             future_target, STEP)

print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (100, 2)
#
#  Target temperature to predict : (5,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='Istoric')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'b',
           label='Valori reale viitoare')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'r',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()
plt.show()

for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))
plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)

multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)

plot_train_history(multi_step_history, 'Capacitatea de învățare a modelului')
# Out:
# (256, 5)
# Epoch 1/100
# 200/200 [==============================] - 122s 273ms/step - loss: 0.7225 - val_loss: 1.2335
# Epoch 2/100
# 200/200 [==============================] - 53s 267ms/step - loss: 0.7160 - val_loss: 3.6398
# Epoch 3/100
# 200/200 [==============================] - 53s 263ms/step - loss: 0.7027 - val_loss: 2.5249
# Epoch 4/100
# 200/200 [==============================] - 60s 299ms/step - loss: 0.6878 - val_loss: 1.3128
# Epoch 5/100
# 200/200 [==============================] - 60s 301ms/step - loss: 0.6767 - val_loss: 1.3370
# Epoch 6/100
# 200/200 [==============================] - 61s 305ms/step - loss: 0.6653 - val_loss: 1.5274
# Epoch 7/100
# 200/200 [==============================] - 59s 294ms/step - loss: 0.6570 - val_loss: 1.4264
# Epoch 8/100
# 200/200 [==============================] - 60s 299ms/step - loss: 0.6492 - val_loss: 2.9881
# Epoch 9/100
# 200/200 [==============================] - 57s 283ms/step - loss: 36.7287 - val_loss: 1.4839
# Epoch 10/100
# 200/200 [==============================] - 57s 287ms/step - loss: 34140.9961 - val_loss: 1.9234
# Epoch 11/100
# 200/200 [==============================] - 58s 289ms/step - loss: 135294.1250 - val_loss: 1.3817
# Epoch 12/100
# 200/200 [==============================] - 60s 299ms/step - loss: 23.9027 - val_loss: 1.4463
# Epoch 13/100
# 200/200 [==============================] - 61s 303ms/step - loss: 46.7609 - val_loss: 1.4238
# Epoch 14/100
# 200/200 [==============================] - 61s 307ms/step - loss: 0.6210 - val_loss: 36478.8945
# Epoch 15/100
# 200/200 [==============================] - 58s 292ms/step - loss: 9401.7920 - val_loss: 1.4123
# Epoch 16/100
# 200/200 [==============================] - 59s 294ms/step - loss: 0.6098 - val_loss: 1.4231
# Epoch 17/100
# 200/200 [==============================] - 61s 306ms/step - loss: 0.6032 - val_loss: 1.4023
# Epoch 18/100
# 200/200 [==============================] - 59s 296ms/step - loss: 0.5986 - val_loss: 1.4343
# Epoch 19/100
# 200/200 [==============================] - 61s 306ms/step - loss: 0.5934 - val_loss: 1.4626
# Epoch 20/100
# 200/200 [==============================] - 57s 284ms/step - loss: 0.5882 - val_loss: 1.4616
# Epoch 21/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.5832 - val_loss: 1.4661
# Epoch 22/100
# 200/200 [==============================] - 59s 297ms/step - loss: 0.5787 - val_loss: 1.4650
# Epoch 23/100
# 200/200 [==============================] - 58s 288ms/step - loss: 0.5742 - val_loss: 1.4914
# Epoch 24/100
# 200/200 [==============================] - 56s 281ms/step - loss: 0.5702 - val_loss: 1.5221
# Epoch 25/100
# 200/200 [==============================] - 59s 297ms/step - loss: 0.5663 - val_loss: 1.5286
# Epoch 26/100
# 200/200 [==============================] - 59s 295ms/step - loss: 0.5629 - val_loss: 1.6086
# Epoch 27/100
# 200/200 [==============================] - 59s 296ms/step - loss: 0.5590 - val_loss: 1.5997
# Epoch 28/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.5554 - val_loss: 1.6876
# Epoch 29/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.5514 - val_loss: 1.7235
# Epoch 30/100
# 200/200 [==============================] - 59s 292ms/step - loss: 0.5484 - val_loss: 1.6238
# Epoch 31/100
# 200/200 [==============================] - 61s 304ms/step - loss: 0.5447 - val_loss: 1.6559
# Epoch 32/100
# 200/200 [==============================] - 61s 305ms/step - loss: 0.5419 - val_loss: 1.6889
# Epoch 33/100
# 200/200 [==============================] - 57s 287ms/step - loss: 0.5383 - val_loss: 1.6624
# Epoch 34/100
# 200/200 [==============================] - 56s 283ms/step - loss: 0.5356 - val_loss: 1.6330
# Epoch 35/100
# 200/200 [==============================] - 58s 288ms/step - loss: 0.5327 - val_loss: 1.6266
# Epoch 36/100
# 200/200 [==============================] - 60s 301ms/step - loss: 0.5301 - val_loss: 1.6184
# Epoch 37/100
# 200/200 [==============================] - 59s 297ms/step - loss: 0.5272 - val_loss: 1.6746
# Epoch 38/100
# 200/200 [==============================] - 59s 293ms/step - loss: 0.5245 - val_loss: 1.6463
# Epoch 39/100
# 200/200 [==============================] - 60s 297ms/step - loss: 0.5220 - val_loss: 1.6418
# Epoch 40/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.5194 - val_loss: 1.6179
# Epoch 41/100
# 200/200 [==============================] - 59s 297ms/step - loss: 0.5162 - val_loss: 1.6390
# Epoch 42/100
# 200/200 [==============================] - 57s 284ms/step - loss: 0.5146 - val_loss: 1.6179
# Epoch 43/100
# 200/200 [==============================] - 57s 285ms/step - loss: 0.5118 - val_loss: 1.6287
# Epoch 44/100
# 200/200 [==============================] - 59s 296ms/step - loss: 0.5090 - val_loss: 1.5845
# Epoch 45/100
# 200/200 [==============================] - 59s 294ms/step - loss: 0.5064 - val_loss: 1.5803
# Epoch 46/100
# 200/200 [==============================] - 61s 305ms/step - loss: 0.5036 - val_loss: 1.5808
# Epoch 47/100
# 200/200 [==============================] - 57s 286ms/step - loss: 0.5015 - val_loss: 1.5779
# Epoch 48/100
# 200/200 [==============================] - 60s 301ms/step - loss: 0.4987 - val_loss: 1.5720
# Epoch 49/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.4962 - val_loss: 1.5947
# Epoch 50/100
# 200/200 [==============================] - 58s 293ms/step - loss: 0.4937 - val_loss: 1.6167
# Epoch 51/100
# 200/200 [==============================] - 59s 294ms/step - loss: 0.4909 - val_loss: 1.5956
# Epoch 52/100
# 200/200 [==============================] - 60s 301ms/step - loss: 0.4881 - val_loss: 1.6177
# Epoch 53/100
# 200/200 [==============================] - 59s 296ms/step - loss: 0.4837 - val_loss: 1.6353
# Epoch 55/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.4816 - val_loss: 1.6581
# Epoch 56/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.4789 - val_loss: 1.6198
# Epoch 57/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.4769 - val_loss: 1.6110
# Epoch 58/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.4744 - val_loss: 1.6314
# Epoch 59/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.4729 - val_loss: 1.6252
# Epoch 60/100
# 200/200 [==============================] - 59s 294ms/step - loss: 0.4707 - val_loss: 1.6074
# Epoch 61/100
# 200/200 [==============================] - 56s 282ms/step - loss: 0.4685 - val_loss: 1.5979
# Epoch 62/100
# 200/200 [==============================] - 56s 279ms/step - loss: 0.4667 - val_loss: 1.6012
# Epoch 63/100
# 200/200 [==============================] - 58s 292ms/step - loss: 0.4644 - val_loss: 1.6009
# Epoch 64/100
# 200/200 [==============================] - 56s 282ms/step - loss: 0.4626 - val_loss: 1.5896
# Epoch 65/100
# 200/200 [==============================] - 58s 292ms/step - loss: 0.4605 - val_loss: 1.5886
# Epoch 66/100
# 200/200 [==============================] - 58s 293ms/step - loss: 0.4586 - val_loss: 1.5692
# Epoch 67/100
# 200/200 [==============================] - 57s 284ms/step - loss: 0.4570 - val_loss: 1.5553
# Epoch 68/100
# 200/200 [==============================] - 61s 304ms/step - loss: 0.4548 - val_loss: 1.5649
# Epoch 69/100
# 200/200 [==============================] - 61s 305ms/step - loss: 0.4187 - val_loss: 1.6033
# Epoch 90/100
# 200/200 [==============================] - 60s 301ms/step - loss: 0.4172 - val_loss: 1.5895
# Epoch 91/100
# 200/200 [==============================] - 58s 292ms/step - loss: 0.4160 - val_loss: 1.5907
# Epoch 92/100
# 200/200 [==============================] - 44s 220ms/step - loss: 0.4139 - val_loss: 1.6028
# Epoch 93/100
# 200/200 [==============================] - 43s 215ms/step - loss: 0.4127 - val_loss: 1.5911
# Epoch 94/100
# 200/200 [==============================] - 44s 219ms/step - loss: 0.4109 - val_loss: 1.5776
# Epoch 95/100
# 200/200 [==============================] - 43s 213ms/step - loss: 0.4094 - val_loss: 1.5993
# Epoch 96/100
# 200/200 [==============================] - 44s 222ms/step - loss: 0.4082 - val_loss: 1.5919
# Epoch 97/100
# 200/200 [==============================] - 31s 155ms/step - loss: 0.4066 - val_loss: 1.6189
# Epoch 98/100
# 200/200 [==============================] - 29s 147ms/step - loss: 0.4049 - val_loss: 1.6056
# Epoch 99/100
# 200/200 [==============================] - 29s 145ms/step - loss: 0.4039 - val_loss: 1.6132
# Epoch 100/100
# 200/200 [==============================] - 29s 147ms/step - loss: 0.4021 - val_loss: 1.6076

# %%
#Predict a multi-step future

predicted=(multi_step_model.predict(x)[0])*data_std[1]+data_mean[1]
history=(x[0])*data_std[1]+data_mean[1]
true_future=(y[0])*data_std[1]+data_mean[1]

for x, y in val_data_multi.take(1):
  multi_step_plot(history, true_future, predicted)


from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(true_future, predicted))
print(rmse)
# Out:
# 0.006266784250385418
