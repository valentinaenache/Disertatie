# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf
df = pd.read_excel('^IXIC.xlsx')

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)
TRAIN_SPLIT = 0.7
tf.random.set_seed(13)

# %%
#Predictia seriei de timp univariate
uni_data = df['Log return ^IXIC']
uni_data.index = df['Date']
print(uni_data.head())

uni_data.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()
# Out:
# Date
# 2012-01-03    0.000000
# 2012-01-04   -0.000136
# 2012-01-05    0.008085
# 2012-01-06    0.001632
# 2012-01-09    0.000875
# Name: Log return ^IXIC, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

uni_data_train, uni_data_test = train_test_split(uni_data, train_size=0.7, test_size=0.3, shuffle=False)
uni_data = uni_data.values

# %%
uni_train_mean = uni_data_train.mean()
uni_train_std = uni_data_train.std()

uni_data = (uni_data-uni_train_mean)/uni_train_std

univariate_past_history = 100
univariate_future_target = 10

x_train_uni, y_train_uni = univariate_data(uni_data, 0, len(uni_data_train),
                                           univariate_past_history,
                                           univariate_future_target)
x_val_uni, y_val_uni = univariate_data(uni_data, len(uni_data_train), None,
                                       univariate_past_history,
                                       univariate_future_target)

print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-0.07348581]
#  [-0.08851077]
#  [ 0.82061527]
#  [ 0.10694559]
#  [ 0.02323662]
#  [ 0.99305647]
#  [ 0.26398337]
#  [ 0.49371613]
#  [-0.64436282]
#  [ 0.63448796]
#  [ 1.60121585]
#  [ 0.66743958]
#  [-0.13815335]
#  [-0.17392766]
#  [ 0.02457277]
#  [ 1.17618416]
#  [-0.58592771]
#  [-0.2546329 ]
#  [ 1.27136873]
#  [ 0.3686084 ]
#  [ 1.69037857]
#  [-0.2132412 ]
#  [ 0.0061291 ]
#  [ 0.37416621]
#  [ 0.35686804]
#  [-0.95911498]
#  [ 0.96918   ]
#  [-0.05688185]
#  [-0.67861912]
#  [ 1.58347532]
#  [-0.37539918]
#  [-0.19380479]
#  [-0.65255724]
#  [ 0.82053699]
#  [ 0.17940146]
#  [ 0.01639464]
#  [ 0.69185185]
#  [-0.81161242]
#  [ 0.74643184]
#  [-0.54731579]
#  [-1.03289863]
#  [-1.58898169]
#  [ 0.88629835]
#  [ 1.22704347]
#  [ 0.5916335 ]
#  [-0.24680816]
#  [ 1.99077019]
#  [-0.04256622]
#  [ 0.49383705]
#  [-0.1136575 ]
#  [ 0.75801088]
#  [-0.22339078]
#  [-0.03140134]
#  [-0.50582215]
#  [ 0.09243768]
#  [ 1.87900815]
#  [-0.1521309 ]
#  [-0.62024299]
#  [-0.41590884]
#  [-0.20896751]
#  [ 0.92813328]
#  [-0.29098042]
#  [-1.70066392]
#  [ 0.37289536]
#  [-1.27972339]
#  [-2.11951384]
#  [ 0.85568822]
#  [ 1.35032498]
#  [-1.68551478]
#  [-0.91874501]
#  [ 1.92213761]
#  [-0.48746973]
#  [-0.9483947 ]
#  [-0.33521842]
#  [-1.1846986 ]
#  [-0.40343245]
#  [ 2.43790261]
#  [ 0.68965248]
#  [ 0.59833158]
#  [-0.89946865]
#  [ 0.07451112]
#  [ 0.2671164 ]
#  [-1.36576793]
#  [-2.58673908]
#  [-0.02038662]
#  [-0.50389721]
#  [-0.50821921]
#  [-0.1138139 ]
#  [-0.06669443]
#  [-1.25729605]
#  [-0.41002105]
#  [-0.82963915]
#  [-2.42023901]
#  [-1.45367152]
#  [ 2.61629178]
#  [-0.38969005]
#  [ 0.35568685]
#  [-0.49098178]
#  [-0.14555298]
#  [ 1.22285438]]
#
#  Target to predict
# -1.0289738230778476

# %%
def create_time_steps(length):
  return list(range(-length, 0))

def show_plot(plot_data, delta, title):
  labels = ['Istoric', 'Valoarea reală din viitor', 'Predicția modelului']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

    plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example')
plt.show()

# %%
def baseline(history):
  return np.mean(history)

show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 0,
           'Model predicție de bază')
plt.show()

BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)

EVALUATION_INTERVAL = 200
EPOCHS = 100

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
for x, y in val_univariate.take(1):
  plot = show_plot([x[0].numpy(), y[0].numpy(),
                    simple_lstm_model.predict(x)[0]], 0, 'Predicție LTSM')
  plot.show()

plt.show()
# Out:
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 7s 27ms/step - loss: 0.7203 - val_loss: 1.2384
# Epoch 2/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7193 - val_loss: 1.2409
# Epoch 3/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7189 - val_loss: 1.2496
# Epoch 4/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7179 - val_loss: 1.2530
# Epoch 5/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7183 - val_loss: 1.2557
# Epoch 6/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7169 - val_loss: 1.2573
# Epoch 7/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7166 - val_loss: 1.2620
# Epoch 8/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7159 - val_loss: 1.2644
# Epoch 9/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7160 - val_loss: 1.2699
# Epoch 10/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7144 - val_loss: 1.2716
# Epoch 11/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7134 - val_loss: 1.2748
# Epoch 12/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7110 - val_loss: 1.2717
# Epoch 13/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7094 - val_loss: 1.2727
# Epoch 14/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7074 - val_loss: 1.2673
# Epoch 15/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7043 - val_loss: 1.2628
# Epoch 16/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.7014 - val_loss: 1.2686
# Epoch 17/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6998 - val_loss: 1.2676
# Epoch 18/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6978 - val_loss: 1.2787
# Epoch 19/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6980 - val_loss: 1.2792
# Epoch 20/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6967 - val_loss: 1.2733
# Epoch 21/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6990 - val_loss: 1.2800
# Epoch 22/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.6943 - val_loss: 1.2815
# Epoch 23/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6945 - val_loss: 1.2869
# Epoch 24/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6919 - val_loss: 1.2885
# Epoch 25/100
# 200/200 [==============================] - 4s 22ms/step - loss: 0.6911 - val_loss: 1.2934
# Epoch 26/100
# 200/200 [==============================] - 5s 23ms/step - loss: 0.7053 - val_loss: 1.2818
# Epoch 27/100
# 200/200 [==============================] - 5s 24ms/step - loss: 0.6951 - val_loss: 1.3034
# Epoch 28/100
# 200/200 [==============================] - 5s 25ms/step - loss: 0.6893 - val_loss: 1.3069
# Epoch 29/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6880 - val_loss: 1.3262
# Epoch 30/100
# 200/200 [==============================] - 6s 30ms/step - loss: 0.6877 - val_loss: 1.3275
# Epoch 31/100
# 200/200 [==============================] - 6s 30ms/step - loss: 0.6893 - val_loss: 1.3176
# Epoch 32/100
# 200/200 [==============================] - 7s 34ms/step - loss: 0.6987 - val_loss: 1.2770
# Epoch 33/100
# 200/200 [==============================] - 7s 38ms/step - loss: 0.6909 - val_loss: 1.2825
# Epoch 34/100
# 200/200 [==============================] - 8s 42ms/step - loss: 0.6881 - val_loss: 1.2831
# Epoch 35/100
# 200/200 [==============================] - 8s 42ms/step - loss: 0.6892 - val_loss: 1.2835
# Epoch 36/100
# 200/200 [==============================] - 8s 41ms/step - loss: 0.6910 - val_loss: 1.2847
# Epoch 37/100
# 200/200 [==============================] - 8s 41ms/step - loss: 0.6885 - val_loss: 1.2820
# Epoch 38/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6899 - val_loss: 1.2775
# Epoch 39/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6929 - val_loss: 1.2803
# Epoch 40/100
# 200/200 [==============================] - 8s 42ms/step - loss: 0.6864 - val_loss: 1.2852
# Epoch 41/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.6860 - val_loss: 1.2831
# Epoch 42/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6841 - val_loss: 1.2864
# Epoch 43/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.6825 - val_loss: 1.2881
# Epoch 44/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.6811 - val_loss: 1.2880
# Epoch 45/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.6890 - val_loss: 1.2774
# Epoch 46/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6865 - val_loss: 1.2847
# Epoch 47/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6900 - val_loss: 1.2769
# Epoch 48/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.6873 - val_loss: 1.2862
# Epoch 49/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6818 - val_loss: 1.2912
# Epoch 50/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.6818 - val_loss: 1.2825
# Epoch 51/100
# 200/200 [==============================] - 9s 43ms/step - loss: 0.6821 - val_loss: 1.2866
# Epoch 52/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6782 - val_loss: 1.2893
# Epoch 53/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.6801 - val_loss: 1.2856
# Epoch 54/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.6831 - val_loss: 1.3039
# Epoch 55/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6992 - val_loss: 1.2862
# Epoch 56/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6794 - val_loss: 1.2873
# Epoch 57/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6784 - val_loss: 1.2902
# Epoch 58/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6788 - val_loss: 1.3048
# Epoch 59/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.6889 - val_loss: 1.2925
# Epoch 60/100
# 200/200 [==============================] - 11s 53ms/step - loss: 0.6848 - val_loss: 1.2878
# Epoch 61/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.7003 - val_loss: 1.2847
# Epoch 62/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.7003 - val_loss: 1.2924
# Epoch 63/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.6906 - val_loss: 1.2836
# Epoch 64/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6815 - val_loss: 1.2878
# Epoch 65/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.6820 - val_loss: 1.2893
# Epoch 66/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6823 - val_loss: 1.2986
# Epoch 67/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6817 - val_loss: 1.2904
# Epoch 68/100
# 200/200 [==============================] - 8s 42ms/step - loss: 0.6837 - val_loss: 1.2834
# Epoch 69/100
# 200/200 [==============================] - 9s 44ms/step - loss: 0.6857 - val_loss: 1.2840
# Epoch 70/100
# 200/200 [==============================] - 7s 37ms/step - loss: 0.6814 - val_loss: 1.2860
# Epoch 71/100
# 200/200 [==============================] - 6s 30ms/step - loss: 0.6785 - val_loss: 1.2911
# Epoch 72/100
# 200/200 [==============================] - 6s 31ms/step - loss: 0.6751 - val_loss: 1.2899
# Epoch 73/100
# 200/200 [==============================] - 6s 32ms/step - loss: 0.6739 - val_loss: 1.2903
# Epoch 74/100
# 200/200 [==============================] - 6s 31ms/step - loss: 0.6720 - val_loss: 1.2861
# Epoch 75/100
# 200/200 [==============================] - 6s 31ms/step - loss: 0.6751 - val_loss: 1.2903
# Epoch 76/100
# 200/200 [==============================] - 6s 32ms/step - loss: 0.6714 - val_loss: 1.2896
# Epoch 77/100
# 200/200 [==============================] - 6s 31ms/step - loss: 0.6701 - val_loss: 1.2902
# Epoch 78/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6696 - val_loss: 1.2907
# Epoch 79/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6804 - val_loss: 1.2978
# Epoch 80/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6769 - val_loss: 1.2943
# Epoch 81/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6730 - val_loss: 1.2887
# Epoch 82/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6704 - val_loss: 1.2872
# Epoch 83/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6684 - val_loss: 1.2894
# Epoch 84/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6675 - val_loss: 1.2893
# Epoch 85/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6671 - val_loss: 1.2902
# Epoch 86/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6666 - val_loss: 1.2892
# Epoch 87/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6663 - val_loss: 1.2905
# Epoch 88/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6668 - val_loss: 1.2910
# Epoch 89/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6668 - val_loss: 1.2916
# Epoch 90/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6664 - val_loss: 1.2936
# Epoch 91/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6649 - val_loss: 1.2943
# Epoch 92/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6640 - val_loss: 1.2943
# Epoch 93/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6653 - val_loss: 1.2951
# Epoch 94/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6642 - val_loss: 1.2946
# Epoch 95/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6634 - val_loss: 1.2961
# Epoch 96/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6637 - val_loss: 1.2970
# Epoch 97/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6624 - val_loss: 1.2974
# Epoch 98/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6614 - val_loss: 1.2999
# Epoch 99/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6606 - val_loss: 1.3003
# Epoch 100/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6607 - val_loss: 1.3010

# %%
#Forecast a multivariate time series

features_considered = ['Log return JPY', 'Log return ^IXIC']
features = df[features_considered]
features.index = df['Date']
features.head()

features.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()

# %%
multi_data_train, multi_data_test = train_test_split(features, train_size=0.7, test_size=0.3, shuffle=False)

dataset = features.values
data_mean = dataset[:len(multi_data_train)].mean(axis=0)
data_std = dataset[:len(multi_data_train)].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

past_history = 100
future_target = 10
STEP = 1
x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   len(multi_data_train), past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               len(multi_data_train), None, past_history,
                                               future_target, STEP,
                                               single_step=True)

print ('Single window of past history : {}'.format(x_train_single[0].shape))

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)

single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Single window of past history : (100, 2)
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 14s 60ms/step - loss: 0.7164 - val_loss: 1.2538
# Epoch 2/100
# 200/200 [==============================] - 11s 57ms/step - loss: 0.7099 - val_loss: 1.2624
# Epoch 3/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.7002 - val_loss: 1.2787
# Epoch 4/100
# 200/200 [==============================] - 11s 55ms/step - loss: 0.6888 - val_loss: 1.2925
# Epoch 5/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6782 - val_loss: 1.3050
# Epoch 6/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6692 - val_loss: 1.2990
# Epoch 7/100
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6608 - val_loss: 1.3012
# Epoch 8/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6514 - val_loss: 1.3064
# Epoch 9/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.6417 - val_loss: 1.3168
# Epoch 10/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6319 - val_loss: 1.3108
# Epoch 11/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.6233 - val_loss: 1.3276
# Epoch 12/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.6117 - val_loss: 1.3392
# Epoch 13/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.6005 - val_loss: 1.3402
# Epoch 14/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.5908 - val_loss: 1.3410
# Epoch 15/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.5764 - val_loss: 1.3444
# Epoch 16/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.5641 - val_loss: 1.3535
# Epoch 17/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.5522 - val_loss: 1.3604
# Epoch 18/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.5433 - val_loss: 1.3672
# Epoch 19/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.5326 - val_loss: 1.3758
# Epoch 20/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.5232 - val_loss: 1.3703
# Epoch 21/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.5150 - val_loss: 1.3839
# Epoch 22/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.5059 - val_loss: 1.3961
# Epoch 23/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4970 - val_loss: 1.4029
# Epoch 24/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4907 - val_loss: 1.4056
# Epoch 25/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4824 - val_loss: 1.3986
# Epoch 26/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4794 - val_loss: 1.3852
# Epoch 27/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4684 - val_loss: 1.4022
# Epoch 28/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4594 - val_loss: 1.4021
# Epoch 29/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4501 - val_loss: 1.3938
# Epoch 30/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4417 - val_loss: 1.4177
# Epoch 31/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.4319 - val_loss: 1.4174
# Epoch 32/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.4243 - val_loss: 1.4229
# Epoch 33/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4201 - val_loss: 1.4295
# Epoch 34/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.4121 - val_loss: 1.4374
# Epoch 35/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.4052 - val_loss: 1.4499
# Epoch 36/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.4003 - val_loss: 1.4318
# Epoch 37/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3936 - val_loss: 1.4571
# Epoch 38/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3867 - val_loss: 1.4510
# Epoch 39/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3857 - val_loss: 1.4347
# Epoch 40/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3793 - val_loss: 1.4405
# Epoch 41/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3728 - val_loss: 1.4625
# Epoch 42/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.3685 - val_loss: 1.4503
# Epoch 43/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.3646 - val_loss: 1.4586
# Epoch 44/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.3599 - val_loss: 1.4499
# Epoch 45/100
# 200/200 [==============================] - 10s 51ms/step - loss: 0.3539 - val_loss: 1.4384
# Epoch 46/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.3490 - val_loss: 1.4496
# Epoch 47/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.3440 - val_loss: 1.4346
# Epoch 48/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3411 - val_loss: 1.4686
# Epoch 49/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3446 - val_loss: 1.4384
# Epoch 50/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.3327 - val_loss: 1.4454
# Epoch 51/100
# 200/200 [==============================] - 11s 53ms/step - loss: 0.3255 - val_loss: 1.4742
# Epoch 52/100
# 200/200 [==============================] - 11s 56ms/step - loss: 0.3218 - val_loss: 1.4411
# Epoch 53/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3153 - val_loss: 1.4670
# Epoch 54/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.3134 - val_loss: 1.4889
# Epoch 55/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3087 - val_loss: 1.4537
# Epoch 56/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.3060 - val_loss: 1.4765
# Epoch 57/100
# 200/200 [==============================] - 10s 50ms/step - loss: 0.3014 - val_loss: 1.5006
# Epoch 58/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2994 - val_loss: 1.4655
# Epoch 59/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2955 - val_loss: 1.4699
# Epoch 60/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.2926 - val_loss: 1.4696
# Epoch 61/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2891 - val_loss: 1.4805
# Epoch 62/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2862 - val_loss: 1.4960
# Epoch 63/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2826 - val_loss: 1.4895
# Epoch 64/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2818 - val_loss: 1.4853
# Epoch 65/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2808 - val_loss: 1.4829
# Epoch 66/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2769 - val_loss: 1.5068
# Epoch 67/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2711 - val_loss: 1.4779
# Epoch 68/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2689 - val_loss: 1.5002
# Epoch 69/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.2672 - val_loss: 1.5094
# Epoch 70/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2645 - val_loss: 1.5163
# Epoch 71/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2604 - val_loss: 1.5255
# Epoch 72/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2579 - val_loss: 1.5128
# Epoch 73/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2618 - val_loss: 1.5155
# Epoch 74/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2568 - val_loss: 1.5290
# Epoch 75/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2524 - val_loss: 1.5372
# Epoch 76/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2494 - val_loss: 1.5223
# Epoch 77/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2472 - val_loss: 1.5338
# Epoch 78/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2492 - val_loss: 1.5578
# Epoch 79/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2444 - val_loss: 1.5372
# Epoch 80/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2386 - val_loss: 1.5114
# Epoch 81/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2396 - val_loss: 1.5215
# Epoch 82/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2343 - val_loss: 1.5465
# Epoch 83/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2328 - val_loss: 1.5304
# Epoch 84/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2379 - val_loss: 1.5480
# Epoch 85/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.2332 - val_loss: 1.5333
# Epoch 86/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2327 - val_loss: 1.5475
# Epoch 87/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2313 - val_loss: 1.5436
# Epoch 88/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2303 - val_loss: 1.5474
# Epoch 89/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2218 - val_loss: 1.5514
# Epoch 90/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2212 - val_loss: 1.5428
# Epoch 91/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2209 - val_loss: 1.5357
# Epoch 92/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2154 - val_loss: 1.5276
# Epoch 93/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2143 - val_loss: 1.5423
# Epoch 94/100
# 200/200 [==============================] - 9s 45ms/step - loss: 0.2115 - val_loss: 1.5576
# Epoch 95/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.2100 - val_loss: 1.5577
# Epoch 96/100
# 200/200 [==============================] - 10s 52ms/step - loss: 0.2125 - val_loss: 1.5556
# Epoch 97/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.2092 - val_loss: 1.5324
# Epoch 98/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2075 - val_loss: 1.5596
# Epoch 99/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2050 - val_loss: 1.5687
# Epoch 100/100
# 200/200 [==============================] - 9s 46ms/step - loss: 0.2048 - val_loss: 1.5849

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Pierderea setului de testare')
  plt.plot(epochs, val_loss, 'r', label='Pierderea setului de validare')
  plt.title('Capacitatea de generalizare a modelului')
  plt.legend()

  plt.show()
plt.show()

# %%
plot_train_history(single_step_history,
                   'Predicția într-o singură etapă')

for x, y in val_data_single.take(1):
  plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'Single Step Prediction')
  plot.show()
plt.show()

# %%
#Multi-Step model

future_target = 5
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 len(multi_data_train), past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             len(multi_data_train), None, past_history,
                                             future_target, STEP)

print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (100, 2)
#
#  Target temperature to predict : (5,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='Istoric')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'b',
           label='Valori reale viitoare')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'r',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()
plt.show()

for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))
plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)

multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)

plot_train_history(multi_step_history, 'Capacitatea de învățare a modelului')
# Out:
# (256, 5)
# Epoch 1/100
# 200/200 [==============================] - 21s 93ms/step - loss: 1.8719 - val_loss: 1.2427
# Epoch 2/100
# 200/200 [==============================] - 18s 88ms/step - loss: 253709.3750 - val_loss: 1.2538
# Epoch 3/100
# 200/200 [==============================] - 18s 88ms/step - loss: 2.4610 - val_loss: 1.2490
# Epoch 4/100
# 200/200 [==============================] - 18s 89ms/step - loss: 77036.3906 - val_loss: 1.2509
# Epoch 5/100
# 200/200 [==============================] - 20s 102ms/step - loss: 16981.1328 - val_loss: 1.2543
# Epoch 6/100
# 200/200 [==============================] - 23s 114ms/step - loss: 0.7111 - val_loss: 1.2549
# Epoch 7/100
# 200/200 [==============================] - 23s 114ms/step - loss: 0.7049 - val_loss: 1.3197
# Epoch 8/100
# 200/200 [==============================] - 23s 114ms/step - loss: 0.6976 - val_loss: 1.4464
# Epoch 9/100
# 200/200 [==============================] - 23s 114ms/step - loss: 0.6855 - val_loss: 1.4275
# Epoch 10/100
# 200/200 [==============================] - 21s 104ms/step - loss: 0.6725 - val_loss: 1.5555
# Epoch 11/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.6636 - val_loss: 1.4624
# Epoch 12/100
# 200/200 [==============================] - 20s 100ms/step - loss: 0.6565 - val_loss: 1.6343
# Epoch 13/100
# 200/200 [==============================] - 20s 100ms/step - loss: 0.6496 - val_loss: 1.4451
# Epoch 14/100
# 200/200 [==============================] - 19s 97ms/step - loss: 0.6431 - val_loss: 1.4327
# Epoch 15/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6360 - val_loss: 1.4111
# Epoch 16/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.6296 - val_loss: 1.4230
# Epoch 17/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.6242 - val_loss: 1.4523
# Epoch 18/100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.6189 - val_loss: 1.4738
# Epoch 19/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.6136 - val_loss: 1.4810
# Epoch 20/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.6083 - val_loss: 1.4779
# Epoch 21/100
# 200/200 [==============================] - 19s 96ms/step - loss: 0.6047 - val_loss: 1.4987
# Epoch 22/100
# 200/200 [==============================] - 20s 98ms/step - loss: 0.6008 - val_loss: 1.4794
# Epoch 23/100
# 200/200 [==============================] - 24s 118ms/step - loss: 0.5966 - val_loss: 1.4842
# Epoch 24/100
# 200/200 [==============================] - 24s 122ms/step - loss: 0.5930 - val_loss: 1.5287
# Epoch 25/100
# 200/200 [==============================] - 24s 120ms/step - loss: 0.5890 - val_loss: 1.6023
# Epoch 26/100
# 200/200 [==============================] - 22s 111ms/step - loss: 0.5848 - val_loss: 1.5452
# Epoch 27/100
# 200/200 [==============================] - 20s 101ms/step - loss: 0.5801 - val_loss: 1.5665
# Epoch 28/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.5754 - val_loss: 1.5540
# Epoch 29/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5706 - val_loss: 1.5504
# Epoch 30/100
# 200/200 [==============================] - 22s 111ms/step - loss: 0.5650 - val_loss: 1.5288
# Epoch 31/100
# 200/200 [==============================] - 23s 113ms/step - loss: 0.5604 - val_loss: 1.5110
# Epoch 32/100
# 200/200 [==============================] - 24s 118ms/step - loss: 0.5555 - val_loss: 1.6078
# Epoch 33/100
# 200/200 [==============================] - 25s 124ms/step - loss: 0.5509 - val_loss: 1.7212
# Epoch 34/100
# 200/200 [==============================] - 24s 119ms/step - loss: 9.0479 - val_loss: 9.8657
# Epoch 35/100
# 200/200 [==============================] - 24s 121ms/step - loss: 23.0371 - val_loss: 37.3741
# Epoch 36/100
# 200/200 [==============================] - 23s 116ms/step - loss: 1106879616.0000 - val_loss: 121.9974
# Epoch 37/100
# 200/200 [==============================] - 24s 121ms/step - loss: 2044.4570 - val_loss: 1.2870
# Epoch 38/100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.6022 - val_loss: 1.4209
# Epoch 39/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.5622 - val_loss: 2.0678
# Epoch 40/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.5496 - val_loss: 1.7881
# Epoch 41/100
# 200/200 [==============================] - 23s 113ms/step - loss: 0.5402 - val_loss: 1.7104
# Epoch 42/100
# 200/200 [==============================] - 23s 114ms/step - loss: 0.5328 - val_loss: 1.4599
# Epoch 43/100
# 200/200 [==============================] - 23s 115ms/step - loss: 0.5265 - val_loss: 1.4830
# Epoch 44/100
# 200/200 [==============================] - 23s 114ms/step - loss: 0.5213 - val_loss: 1.5025
# Epoch 45/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5166 - val_loss: 1.5235
# Epoch 46/100
# 200/200 [==============================] - 20s 100ms/step - loss: 0.5122 - val_loss: 1.5282
# Epoch 47/100
# 200/200 [==============================] - 19s 96ms/step - loss: 0.5082 - val_loss: 1.5267
# Epoch 48/100
# 200/200 [==============================] - 19s 97ms/step - loss: 0.5035 - val_loss: 1.4865
# Epoch 49/100
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4998 - val_loss: 1.5261
# Epoch 50/100
# 200/200 [==============================] - 19s 93ms/step - loss: 0.4958 - val_loss: 1.5189
# Epoch 51/100
# 200/200 [==============================] - 19s 96ms/step - loss: 0.4924 - val_loss: 1.5212
# Epoch 52/100
# 200/200 [==============================] - 24s 119ms/step - loss: 0.4888 - val_loss: 1.5183
# Epoch 53/100
# 200/200 [==============================] - 24s 120ms/step - loss: 0.4851 - val_loss: 1.5395
# Epoch 54/100
# 200/200 [==============================] - 23s 117ms/step - loss: 0.4808 - val_loss: 1.5029
# Epoch 55/100
# 200/200 [==============================] - 24s 121ms/step - loss: 0.4765 - val_loss: 1.5147
# Epoch 56/100
# 200/200 [==============================] - 24s 119ms/step - loss: 0.4728 - val_loss: 1.5143
# Epoch 57/100
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4688 - val_loss: 1.5218
# Epoch 58/100
# 200/200 [==============================] - 19s 97ms/step - loss: 0.4649 - val_loss: 1.5167
# Epoch 59/100
# 200/200 [==============================] - 20s 100ms/step - loss: 0.4616 - val_loss: 1.4883
# Epoch 60/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.4575 - val_loss: 1.4758
# Epoch 61/100
# 200/200 [==============================] - 20s 99ms/step - loss: 0.4540 - val_loss: 1.5059
# Epoch 62/100
# 200/200 [==============================] - 24s 122ms/step - loss: 0.4502 - val_loss: 1.4892
# Epoch 63/100
# 200/200 [==============================] - 23s 117ms/step - loss: 0.4458 - val_loss: 1.4720
# Epoch 64/100
# 200/200 [==============================] - 25s 123ms/step - loss: 0.4467 - val_loss: 1.5106
# Epoch 65/100
# 200/200 [==============================] - 24s 121ms/step - loss: 0.4765 - val_loss: 1.4464
# Epoch 66/100
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4390 - val_loss: 1.4888
# Epoch 67/100
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4339 - val_loss: 1.5123
# Epoch 68/100
# 200/200 [==============================] - 23s 117ms/step - loss: 0.4284 - val_loss: 1.4798
# Epoch 69/100
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4252 - val_loss: 1.5055
# Epoch 70/100
# 200/200 [==============================] - 24s 119ms/step - loss: 3760.2229 - val_loss: 51395.8828
# Epoch 71/100
# 200/200 [==============================] - 25s 124ms/step - loss: 395.9067 - val_loss: 1.5007
# Epoch 72/100
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4425 - val_loss: 1.5024
# Epoch 73/100
# 200/200 [==============================] - 24s 120ms/step - loss: 0.4237 - val_loss: 1.5104
# Epoch 74/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4140 - val_loss: 1.4948
# Epoch 75/100
# 200/200 [==============================] - 25s 125ms/step - loss: 0.4121 - val_loss: 1.5202
# Epoch 76/100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.4066 - val_loss: 1.5250
# Epoch 77/100
# 200/200 [==============================] - 23s 117ms/step - loss: 0.4032 - val_loss: 1.5466
# Epoch 78/100
# 200/200 [==============================] - 23s 116ms/step - loss: 0.3974 - val_loss: 1.5668
# Epoch 79/100
# 200/200 [==============================] - 26s 129ms/step - loss: 0.3943 - val_loss: 1.5831
# Epoch 80/100
# 200/200 [==============================] - 26s 128ms/step - loss: 0.3889 - val_loss: 1.5603
# Epoch 81/100
# 200/200 [==============================] - 21s 103ms/step - loss: 0.3849 - val_loss: 1.5799
# Epoch 82/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.3802 - val_loss: 1.5646
# Epoch 83/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3767 - val_loss: 1.6133
# Epoch 84/100
# 200/200 [==============================] - 24s 120ms/step - loss: 0.3721 - val_loss: 1.5884
# Epoch 85/100
# 200/200 [==============================] - 26s 129ms/step - loss: 0.3681 - val_loss: 1.5808
# Epoch 86/100
# 200/200 [==============================] - 24s 121ms/step - loss: 0.3723 - val_loss: 1.6239
# Epoch 87/100
# 200/200 [==============================] - 24s 122ms/step - loss: 0.3819 - val_loss: 1.6130
# Epoch 88/100
# 200/200 [==============================] - 25s 124ms/step - loss: 0.3621 - val_loss: 1.6300
# Epoch 89/100
# 200/200 [==============================] - 25s 127ms/step - loss: 0.3580 - val_loss: 1.5796
# Epoch 90/100
# 200/200 [==============================] - 25s 124ms/step - loss: 0.3553 - val_loss: 1.5913
# Epoch 91/100
# 200/200 [==============================] - 24s 119ms/step - loss: 0.3518 - val_loss: 1.6210
# Epoch 92/100
# 200/200 [==============================] - 25s 124ms/step - loss: 0.3486 - val_loss: 1.5699
# Epoch 93/100
# 200/200 [==============================] - 24s 118ms/step - loss: 0.3452 - val_loss: 1.5713
# Epoch 94/100
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3410 - val_loss: 1.5742
# Epoch 95/100
# 200/200 [==============================] - 28s 142ms/step - loss: 0.3646 - val_loss: 1.7763
# Epoch 96/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.3392 - val_loss: 1.5599
# Epoch 97/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.3366 - val_loss: 1.5913
# Epoch 98/100
# 200/200 [==============================] - 20s 99ms/step - loss: 0.3329 - val_loss: 1.5740
# Epoch 99/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.3300 - val_loss: 1.5971
# Epoch 100/100
# 200/200 [==============================] - 25s 128ms/step - loss: 0.3264 - val_loss: 1.6169

# %%
#Predict a multi-step future

predicted=(multi_step_model.predict(x)[0])*data_std[1]+data_mean[1]
history=(x[0])*data_std[1]+data_mean[1]
true_future=(y[0])*data_std[1]+data_mean[1]

for x, y in val_data_multi.take(1):
  multi_step_plot(history, true_future, predicted)


from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(true_future, predicted))
print(rmse)
# Out:
# 0.008696329945837654
