# %%
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf
df = pd.read_excel('^IXIC.xlsx')

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)
TRAIN_SPLIT = 0.7
tf.random.set_seed(13)

# %%
#Predictia seriei de timp univariate
uni_data = df['Log return ^IXIC']
uni_data.index = df['Date']
print(uni_data.head())

uni_data.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()
# Out:
# Date
# 2012-01-03    0.000000
# 2012-01-04   -0.000136
# 2012-01-05    0.008085
# 2012-01-06    0.001632
# 2012-01-09    0.000875
# Name: Log return ^IXIC, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

uni_data_train, uni_data_test = train_test_split(uni_data, train_size=0.7, test_size=0.3, shuffle=False)
uni_data = uni_data.values

# %%
uni_train_mean = uni_data_train.mean()
uni_train_std = uni_data_train.std()

uni_data = (uni_data-uni_train_mean)/uni_train_std

univariate_past_history = 100
univariate_future_target = 10

x_train_uni, y_train_uni = univariate_data(uni_data, 0, len(uni_data_train),
                                           univariate_past_history,
                                           univariate_future_target)
x_val_uni, y_val_uni = univariate_data(uni_data, len(uni_data_train), None,
                                       univariate_past_history,
                                       univariate_future_target)

print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-0.07348581]
#  [-0.08851077]
#  [ 0.82061527]
#  [ 0.10694559]
#  [ 0.02323662]
#  [ 0.99305647]
#  [ 0.26398337]
#  [ 0.49371613]
#  [-0.64436282]
#  [ 0.63448796]
#  [ 1.60121585]
#  [ 0.66743958]
#  [-0.13815335]
#  [-0.17392766]
#  [ 0.02457277]
#  [ 1.17618416]
#  [-0.58592771]
#  [-0.2546329 ]
#  [ 1.27136873]
#  [ 0.3686084 ]
#  [ 1.69037857]
#  [-0.2132412 ]
#  [ 0.0061291 ]
#  [ 0.37416621]
#  [ 0.35686804]
#  [-0.95911498]
#  [ 0.96918   ]
#  [-0.05688185]
#  [-0.67861912]
#  [ 1.58347532]
#  [-0.37539918]
#  [-0.19380479]
#  [-0.65255724]
#  [ 0.82053699]
#  [ 0.17940146]
#  [ 0.01639464]
#  [ 0.69185185]
#  [-0.81161242]
#  [ 0.74643184]
#  [-0.54731579]
#  [-1.03289863]
#  [-1.58898169]
#  [ 0.88629835]
#  [ 1.22704347]
#  [ 0.5916335 ]
#  [-0.24680816]
#  [ 1.99077019]
#  [-0.04256622]
#  [ 0.49383705]
#  [-0.1136575 ]
#  [ 0.75801088]
#  [-0.22339078]
#  [-0.03140134]
#  [-0.50582215]
#  [ 0.09243768]
#  [ 1.87900815]
#  [-0.1521309 ]
#  [-0.62024299]
#  [-0.41590884]
#  [-0.20896751]
#  [ 0.92813328]
#  [-0.29098042]
#  [-1.70066392]
#  [ 0.37289536]
#  [-1.27972339]
#  [-2.11951384]
#  [ 0.85568822]
#  [ 1.35032498]
#  [-1.68551478]
#  [-0.91874501]
#  [ 1.92213761]
#  [-0.48746973]
#  [-0.9483947 ]
#  [-0.33521842]
#  [-1.1846986 ]
#  [-0.40343245]
#  [ 2.43790261]
#  [ 0.68965248]
#  [ 0.59833158]
#  [-0.89946865]
#  [ 0.07451112]
#  [ 0.2671164 ]
#  [-1.36576793]
#  [-2.58673908]
#  [-0.02038662]
#  [-0.50389721]
#  [-0.50821921]
#  [-0.1138139 ]
#  [-0.06669443]
#  [-1.25729605]
#  [-0.41002105]
#  [-0.82963915]
#  [-2.42023901]
#  [-1.45367152]
#  [ 2.61629178]
#  [-0.38969005]
#  [ 0.35568685]
#  [-0.49098178]
#  [-0.14555298]
#  [ 1.22285438]]
#
#  Target to predict
# -1.0289738230778476

# %%
def create_time_steps(length):
  return list(range(-length, 0))

def show_plot(plot_data, delta, title):
  labels = ['Istoric', 'Valoarea reală din viitor', 'Predicția modelului']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

    plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example')
plt.show()

# %%
def baseline(history):
  return np.mean(history)

show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 0,
           'Model predicție de bază')
plt.show()

BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)

EVALUATION_INTERVAL = 200
EPOCHS = 100

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
for x, y in val_univariate.take(1):
  plot = show_plot([x[0].numpy(), y[0].numpy(),
                    simple_lstm_model.predict(x)[0]], 0, 'Predicție LTSM')
  plot.show()

plt.show()
# Out:
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 8s 32ms/step - loss: 0.7203 - val_loss: 1.2384
# Epoch 2/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7193 - val_loss: 1.2409
# Epoch 3/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.7189 - val_loss: 1.2496
# Epoch 4/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7179 - val_loss: 1.2530
# Epoch 5/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7183 - val_loss: 1.2557
# Epoch 6/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7169 - val_loss: 1.2573
# Epoch 7/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7166 - val_loss: 1.2620
# Epoch 8/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7159 - val_loss: 1.2644
# Epoch 9/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7160 - val_loss: 1.2699
# Epoch 10/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7144 - val_loss: 1.2716
# Epoch 11/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7134 - val_loss: 1.2748
# Epoch 12/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.7110 - val_loss: 1.2717
# Epoch 13/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7094 - val_loss: 1.2727
# Epoch 14/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7074 - val_loss: 1.2673
# Epoch 15/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7043 - val_loss: 1.2628
# Epoch 16/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.7014 - val_loss: 1.2686
# Epoch 17/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6998 - val_loss: 1.2676
# Epoch 18/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6978 - val_loss: 1.2787
# Epoch 19/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6980 - val_loss: 1.2792
# Epoch 20/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6967 - val_loss: 1.2733
# Epoch 21/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6990 - val_loss: 1.2800
# Epoch 22/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6943 - val_loss: 1.2815
# Epoch 23/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6945 - val_loss: 1.2869
# Epoch 24/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6919 - val_loss: 1.2885
# Epoch 25/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6911 - val_loss: 1.2934
# Epoch 26/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.7053 - val_loss: 1.2818
# Epoch 27/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6951 - val_loss: 1.3034
# Epoch 28/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6893 - val_loss: 1.3069
# Epoch 29/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6880 - val_loss: 1.3262
# Epoch 30/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6877 - val_loss: 1.3275
# Epoch 31/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6893 - val_loss: 1.3176
# Epoch 32/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6987 - val_loss: 1.2770
# Epoch 33/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6909 - val_loss: 1.2825
# Epoch 34/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6881 - val_loss: 1.2831
# Epoch 35/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6892 - val_loss: 1.2835
# Epoch 36/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6910 - val_loss: 1.2847
# Epoch 37/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6885 - val_loss: 1.2820
# Epoch 38/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6899 - val_loss: 1.2775
# Epoch 39/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6929 - val_loss: 1.2803
# Epoch 40/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6864 - val_loss: 1.2852
# Epoch 41/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6860 - val_loss: 1.2831
# Epoch 42/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6841 - val_loss: 1.2864
# Epoch 43/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6825 - val_loss: 1.2881
# Epoch 44/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6811 - val_loss: 1.2880
# Epoch 45/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6890 - val_loss: 1.2774
# Epoch 46/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6865 - val_loss: 1.2847
# Epoch 47/100
# 200/200 [==============================] - 6s 30ms/step - loss: 0.6900 - val_loss: 1.2769
# Epoch 48/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6873 - val_loss: 1.2862
# Epoch 49/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6818 - val_loss: 1.2912
# Epoch 50/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6818 - val_loss: 1.2825
# Epoch 51/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6821 - val_loss: 1.2866
# Epoch 52/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6782 - val_loss: 1.2893
# Epoch 53/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6801 - val_loss: 1.2856
# Epoch 54/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6831 - val_loss: 1.3039
# Epoch 55/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6992 - val_loss: 1.2862
# Epoch 56/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6794 - val_loss: 1.2873
# Epoch 57/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6784 - val_loss: 1.2902
# Epoch 58/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6788 - val_loss: 1.3048
# Epoch 59/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6889 - val_loss: 1.2925
# Epoch 60/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6848 - val_loss: 1.2878
# Epoch 61/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.7003 - val_loss: 1.2847
# Epoch 62/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.7003 - val_loss: 1.2924
# Epoch 63/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6906 - val_loss: 1.2836
# Epoch 64/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6815 - val_loss: 1.2878
# Epoch 65/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6820 - val_loss: 1.2893
# Epoch 66/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6823 - val_loss: 1.2986
# Epoch 67/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6817 - val_loss: 1.2904
# Epoch 68/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6837 - val_loss: 1.2834
# Epoch 69/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6857 - val_loss: 1.2840
# Epoch 70/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6814 - val_loss: 1.2860
# Epoch 71/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6785 - val_loss: 1.2911
# Epoch 72/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6751 - val_loss: 1.2899
# Epoch 73/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6739 - val_loss: 1.2903
# Epoch 74/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6720 - val_loss: 1.2861
# Epoch 75/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6751 - val_loss: 1.2903
# Epoch 76/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6714 - val_loss: 1.2896
# Epoch 77/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6701 - val_loss: 1.2902
# Epoch 78/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6696 - val_loss: 1.2907
# Epoch 79/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6804 - val_loss: 1.2978
# Epoch 80/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6769 - val_loss: 1.2943
# Epoch 81/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6730 - val_loss: 1.2887
# Epoch 82/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6704 - val_loss: 1.2872
# Epoch 83/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6684 - val_loss: 1.2894
# Epoch 84/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6675 - val_loss: 1.2893
# Epoch 85/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6671 - val_loss: 1.2902
# Epoch 86/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6666 - val_loss: 1.2892
# Epoch 87/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6663 - val_loss: 1.2905
# Epoch 88/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6668 - val_loss: 1.2910
# Epoch 89/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6668 - val_loss: 1.2916
# Epoch 90/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6664 - val_loss: 1.2936
# Epoch 91/100
# 200/200 [==============================] - 6s 30ms/step - loss: 0.6649 - val_loss: 1.2943
# Epoch 92/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6640 - val_loss: 1.2943
# Epoch 93/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6653 - val_loss: 1.2951
# Epoch 94/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6642 - val_loss: 1.2946
# Epoch 95/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6634 - val_loss: 1.2961
# Epoch 96/100
# 200/200 [==============================] - 6s 28ms/step - loss: 0.6637 - val_loss: 1.2970
# Epoch 97/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6624 - val_loss: 1.2974
# Epoch 98/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6614 - val_loss: 1.2999
# Epoch 99/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6606 - val_loss: 1.3003
# Epoch 100/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.6607 - val_loss: 1.3010

# %%
#Forecast a multivariate time series

features_considered = ['Log return GBP', 'Log return ^IXIC']
features = df[features_considered]
features.index = df['Date']
features.head()

features.plot(subplots=True)
plt.xlabel('Perioada')
plt.show()

# %%
multi_data_train, multi_data_test = train_test_split(features, train_size=0.7, test_size=0.3, shuffle=False)

dataset = features.values
data_mean = dataset[:len(multi_data_train)].mean(axis=0)
data_std = dataset[:len(multi_data_train)].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

past_history = 100
future_target = 10
STEP = 1
x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   len(multi_data_train), past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               len(multi_data_train), None, past_history,
                                               future_target, STEP,
                                               single_step=True)

print ('Single window of past history : {}'.format(x_train_single[0].shape))

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)

single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Single window of past history : (100, 2)
# (256, 1)
# Epoch 1/100
# 200/200 [==============================] - 15s 64ms/step - loss: 0.7179 - val_loss: 1.2491
# Epoch 2/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.7128 - val_loss: 1.2620
# Epoch 3/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.7025 - val_loss: 1.2794
# Epoch 4/100
# 200/200 [==============================] - 12s 63ms/step - loss: 0.6924 - val_loss: 1.2836
# Epoch 5/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6842 - val_loss: 1.2925
# Epoch 6/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6761 - val_loss: 1.2881
# Epoch 7/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6663 - val_loss: 1.2949
# Epoch 8/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6539 - val_loss: 1.2997
# Epoch 9/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6439 - val_loss: 1.2983
# Epoch 10/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6351 - val_loss: 1.3020
# Epoch 11/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6271 - val_loss: 1.3070
# Epoch 12/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6189 - val_loss: 1.3035
# Epoch 13/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6099 - val_loss: 1.3096
# Epoch 14/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5967 - val_loss: 1.3228
# Epoch 15/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5829 - val_loss: 1.3224
# Epoch 16/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5689 - val_loss: 1.3232
# Epoch 17/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5563 - val_loss: 1.3252
# Epoch 18/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5427 - val_loss: 1.3284
# Epoch 19/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5286 - val_loss: 1.3326
# Epoch 20/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5166 - val_loss: 1.3355
# Epoch 21/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5059 - val_loss: 1.3463
# Epoch 22/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4954 - val_loss: 1.3427
# Epoch 23/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4870 - val_loss: 1.3463
# Epoch 24/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4793 - val_loss: 1.3473
# Epoch 25/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4709 - val_loss: 1.3556
# Epoch 26/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4633 - val_loss: 1.3621
# Epoch 27/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4546 - val_loss: 1.3618
# Epoch 28/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.4482 - val_loss: 1.3758
# Epoch 29/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4387 - val_loss: 1.3684
# Epoch 30/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4324 - val_loss: 1.3698
# Epoch 31/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4264 - val_loss: 1.3691
# Epoch 32/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4200 - val_loss: 1.3712
# Epoch 33/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4134 - val_loss: 1.3736
# Epoch 34/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4072 - val_loss: 1.3837
# Epoch 35/100
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4007 - val_loss: 1.3883
# Epoch 36/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3940 - val_loss: 1.3902
# Epoch 37/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3883 - val_loss: 1.3920
# Epoch 38/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3818 - val_loss: 1.3967
# Epoch 39/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.3778 - val_loss: 1.3920
# Epoch 40/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3723 - val_loss: 1.3967
# Epoch 41/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3683 - val_loss: 1.4028
# Epoch 42/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3638 - val_loss: 1.4038
# Epoch 43/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3597 - val_loss: 1.4035
# Epoch 44/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3563 - val_loss: 1.4040
# Epoch 45/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3514 - val_loss: 1.4058
# Epoch 46/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3476 - val_loss: 1.4089
# Epoch 47/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.3422 - val_loss: 1.4125
# Epoch 48/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3399 - val_loss: 1.4027
# Epoch 49/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.3352 - val_loss: 1.4037
# Epoch 50/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3329 - val_loss: 1.3991
# Epoch 51/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3277 - val_loss: 1.4087
# Epoch 52/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3234 - val_loss: 1.4039
# Epoch 53/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.3212 - val_loss: 1.4082
# Epoch 54/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.3146 - val_loss: 1.4183
# Epoch 55/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.3118 - val_loss: 1.4216
# Epoch 56/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3077 - val_loss: 1.4208
# Epoch 57/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3051 - val_loss: 1.4240
# Epoch 58/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3015 - val_loss: 1.4182
# Epoch 59/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2972 - val_loss: 1.4186
# Epoch 60/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2962 - val_loss: 1.4310
# Epoch 61/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2902 - val_loss: 1.4170
# Epoch 62/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.2895 - val_loss: 1.4224
# Epoch 63/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.2847 - val_loss: 1.4301
# Epoch 64/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.2842 - val_loss: 1.4355
# Epoch 65/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2782 - val_loss: 1.4413
# Epoch 66/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2780 - val_loss: 1.4237
# Epoch 67/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2739 - val_loss: 1.4320
# Epoch 68/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2705 - val_loss: 1.4446
# Epoch 69/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2693 - val_loss: 1.4488
# Epoch 70/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2658 - val_loss: 1.4486
# Epoch 71/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2625 - val_loss: 1.4683
# Epoch 72/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2624 - val_loss: 1.4540
# Epoch 73/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2590 - val_loss: 1.4545
# Epoch 74/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2540 - val_loss: 1.4723
# Epoch 75/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2535 - val_loss: 1.4573
# Epoch 76/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2508 - val_loss: 1.4723
# Epoch 77/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2474 - val_loss: 1.4778
# Epoch 78/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2455 - val_loss: 1.4623
# Epoch 79/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2422 - val_loss: 1.4558
# Epoch 80/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2409 - val_loss: 1.4686
# Epoch 81/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.2403 - val_loss: 1.4810
# Epoch 82/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2371 - val_loss: 1.4699
# Epoch 83/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.2358 - val_loss: 1.4902
# Epoch 84/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2317 - val_loss: 1.4902
# Epoch 85/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.2313 - val_loss: 1.4915
# Epoch 86/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.2297 - val_loss: 1.5009
# Epoch 87/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.2270 - val_loss: 1.4838
# Epoch 88/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2238 - val_loss: 1.4996
# Epoch 89/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2218 - val_loss: 1.5028
# Epoch 90/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2225 - val_loss: 1.5095
# Epoch 91/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2192 - val_loss: 1.4917
# Epoch 92/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.2171 - val_loss: 1.5055
# Epoch 93/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2165 - val_loss: 1.4962
# Epoch 94/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.2147 - val_loss: 1.5116
# Epoch 95/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2140 - val_loss: 1.5164
# Epoch 96/100
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2112 - val_loss: 1.5026
# Epoch 97/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2079 - val_loss: 1.5112
# Epoch 98/100
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2071 - val_loss: 1.5019
# Epoch 99/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2072 - val_loss: 1.4971
# Epoch 100/100
# 200/200 [==============================] - 12s 62ms/step - loss: 0.2055 - val_loss: 1.5115

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Pierderea setului de testare')
  plt.plot(epochs, val_loss, 'r', label='Pierderea setului de validare')
  plt.title('Capacitatea de generalizare a modelului')
  plt.legend()

  plt.show()
plt.show()

# %%
plot_train_history(single_step_history,
                   'Predicția într-o singură etapă')

for x, y in val_data_single.take(1):
  plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'Single Step Prediction')
  plot.show()
plt.show()

# %%
#Multi-Step model

future_target = 5
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 len(multi_data_train), past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             len(multi_data_train), None, past_history,
                                             future_target, STEP)

print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (100, 2)
#
#  Target temperature to predict : (5,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='Istoric')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'b',
           label='Valori reale viitoare')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'r',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()
plt.show()

for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))
plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)

multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)

plot_train_history(multi_step_history, 'Capacitatea de învățare a modelului')
# Out:
# (256, 5)
# Epoch 1/100
# 200/200 [==============================] - 26s 110ms/step - loss: 0.7193 - val_loss: 1.2341
# Epoch 2/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.7131 - val_loss: 1.2502
# Epoch 3/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.7036 - val_loss: 1.2843
# Epoch 4/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.6940 - val_loss: 1.3076
# Epoch 5/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6860 - val_loss: 2.1715
# Epoch 6/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6775 - val_loss: 4.8273
# Epoch 7/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.6681 - val_loss: 1.6754
# Epoch 8/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6590 - val_loss: 2.0062
# Epoch 9/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6516 - val_loss: 1.5454
# Epoch 10/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6445 - val_loss: 1.9823
# Epoch 11/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6365 - val_loss: 1.3973
# Epoch 12/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6293 - val_loss: 1.3776
# Epoch 13/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.6226 - val_loss: 1.3902
# Epoch 14/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6168 - val_loss: 1.3760
# Epoch 15/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6111 - val_loss: 1.3658
# Epoch 16/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.6063 - val_loss: 1.3451
# Epoch 17/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.6016 - val_loss: 1.3708
# Epoch 18/100
# 200/200 [==============================] - 22s 110ms/step - loss: 0.5962 - val_loss: 1.4178
# Epoch 19/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.5912 - val_loss: 1.3850
# Epoch 20/100
# 200/200 [==============================] - 21s 107ms/step - loss: 0.5854 - val_loss: 1.3710
# Epoch 21/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5813 - val_loss: 1.3750
# Epoch 22/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5765 - val_loss: 1.3860
# Epoch 23/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5716 - val_loss: 1.3798
# Epoch 24/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5671 - val_loss: 1.4015
# Epoch 25/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5627 - val_loss: 1.3949
# Epoch 26/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5583 - val_loss: 1.3848
# Epoch 27/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5539 - val_loss: 1.4009
# Epoch 28/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5502 - val_loss: 1.4037
# Epoch 29/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5463 - val_loss: 1.3944
# Epoch 30/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5422 - val_loss: 1.4047
# Epoch 31/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5384 - val_loss: 1.4082
# Epoch 32/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5344 - val_loss: 1.4136
# Epoch 33/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5308 - val_loss: 1.4415
# Epoch 34/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5269 - val_loss: 1.4384
# Epoch 35/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5227 - val_loss: 1.4174
# Epoch 36/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5186 - val_loss: 1.4423
# Epoch 37/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5149 - val_loss: 1.4436
# Epoch 38/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5117 - val_loss: 1.4517
# Epoch 39/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.5077 - val_loss: 1.4657
# Epoch 40/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.5039 - val_loss: 1.4580
# Epoch 41/100
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4996 - val_loss: 1.4515
# Epoch 42/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4964 - val_loss: 1.4510
# Epoch 43/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4921 - val_loss: 1.4493
# Epoch 44/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4887 - val_loss: 1.4399
# Epoch 45/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4855 - val_loss: 1.4577
# Epoch 46/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4819 - val_loss: 1.4467
# Epoch 47/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4782 - val_loss: 1.4543
# Epoch 48/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4742 - val_loss: 1.4636
# Epoch 49/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4709 - val_loss: 1.4654
# Epoch 50/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4668 - val_loss: 1.4815
# Epoch 51/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4634 - val_loss: 1.5073
# Epoch 52/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4592 - val_loss: 1.4778
# Epoch 53/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4556 - val_loss: 1.4912
# Epoch 54/100
# 200/200 [==============================] - 21s 105ms/step - loss: 0.4524 - val_loss: 1.4549
# Epoch 55/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4487 - val_loss: 1.5050
# Epoch 56/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4453 - val_loss: 1.4474
# Epoch 57/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4413 - val_loss: 1.4945
# Epoch 58/100
# 200/200 [==============================] - 21s 106ms/step - loss: 0.4379 - val_loss: 1.4936
# Epoch 59/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.4345 - val_loss: 1.4900
# Epoch 60/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.4311 - val_loss: 1.4799
# Epoch 61/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.4270 - val_loss: 1.4787
# Epoch 62/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.4229 - val_loss: 1.4720
# Epoch 63/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.4198 - val_loss: 1.5092
# Epoch 64/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.4158 - val_loss: 1.5002
# Epoch 65/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.4119 - val_loss: 1.4753
# Epoch 66/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.4082 - val_loss: 1.4839
# Epoch 67/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.4045 - val_loss: 1.5119
# Epoch 68/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3999 - val_loss: 1.5136
# Epoch 69/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.3973 - val_loss: 1.5229
# Epoch 70/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3921 - val_loss: 1.5135
# Epoch 71/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3883 - val_loss: 1.4949
# Epoch 72/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3837 - val_loss: 1.5426
# Epoch 73/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3793 - val_loss: 1.5536
# Epoch 74/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3740 - val_loss: 1.5471
# Epoch 75/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3698 - val_loss: 1.5462
# Epoch 76/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3650 - val_loss: 1.5569
# Epoch 77/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3599 - val_loss: 1.5452
# Epoch 78/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3550 - val_loss: 1.5643
# Epoch 79/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3505 - val_loss: 1.5659
# Epoch 80/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3469 - val_loss: 1.5502
# Epoch 81/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3431 - val_loss: 1.5338
# Epoch 82/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3386 - val_loss: 1.5394
# Epoch 83/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3359 - val_loss: 1.5583
# Epoch 84/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.3317 - val_loss: 1.5592
# Epoch 85/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3282 - val_loss: 1.5516
# Epoch 86/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3250 - val_loss: 1.5637
# Epoch 87/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3218 - val_loss: 1.5636
# Epoch 88/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3180 - val_loss: 1.5559
# Epoch 89/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3145 - val_loss: 1.5562
# Epoch 90/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.3109 - val_loss: 1.5662
# Epoch 91/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3085 - val_loss: 1.5539
# Epoch 92/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3048 - val_loss: 1.5668
# Epoch 93/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.3017 - val_loss: 1.5761
# Epoch 94/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.2980 - val_loss: 1.5837
# Epoch 95/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.2952 - val_loss: 1.5382
# Epoch 96/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.2920 - val_loss: 1.5443
# Epoch 97/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.2888 - val_loss: 1.5328
# Epoch 98/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.2860 - val_loss: 1.5780
# Epoch 99/100
# 200/200 [==============================] - 17s 85ms/step - loss: 0.2827 - val_loss: 1.5617
# Epoch 100/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.2799 - val_loss: 1.5322

# %%
#Predict a multi-step future

predicted=(multi_step_model.predict(x)[0])*data_std[1]+data_mean[1]
history=(x[0])*data_std[1]+data_mean[1]
true_future=(y[0])*data_std[1]+data_mean[1]

for x, y in val_data_multi.take(1):
  multi_step_plot(history, true_future, predicted)


from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(true_future, predicted))
print(rmse)
# Out:
# 0.011434468896210788
